# %%
from setup import *
companies_df = pd.read_excel(os.path.join(data_dir, 'companies_data.xlsx'))

# %% [markdown]
# # Activity Types

# %%
activity_types = list(companies_df['activity_type'].unique())
print('activity_types:', activity_types)
# Out:
# activity_types: ['WBS', 'TT_Task', 'TT_FinMile', 'TT_Mile', nan]

# %% [markdown]
# **TT_Task**: time dependent activity - likely what you want to focus on for clustering
# **TT_Mile**: start milestone
# **TT_FinMile** finish milestone
# a start milestone would be something like 'begin ground works', and a finish milestone would be 'complete ground works', logistically they're equivalent but one of them denotes a start of something, and the other denotes an end of something.
# **WBS (Work Breakdown Structure)**: An organizational tool, and it is used to split the tasks into categorical sections of the project, so a WBS might be 'Station Foundations', and all tasks/milestones under this WBS will be related to that overall section. WBS's are hierarchical, so you might have:
# 'Station 1'  -> 'Station Foundations' -> 'East Station Foundations' -> 'East Station Digging'
# These would all be different WBS levels, and at each level there may be tasks and milestones, or there may only be tasks/milestones at the lowest level

# %% [markdown]
# # Milestones

# %% [markdown]
# ## Start

# %%
start_ms = list(companies_df['activity_name'][companies_df['activity_type']=='TT_Mile'].unique())
print('start milestones:', start_ms)
# Out:
# start milestones: ['AS BUILT DOCUMENTATION [submittal to customer]', 'System in service', 'Demin Water available for Construction', 'Commence Weekly Winding Insulation Resistance Checks', 'First Del to pad of Modules (Heating Surfaces)', 'HRSG Structure Ready for Modules & Drums', 'Temporary Power Available for GT Lube Oil Flush & Restore', 'Ready for Pre-assembling Pipework MBA/MBP/ MBX/ EKG Piping', 'Condenser Ready for Preassembling Piping', 'Condenser Ready for PAB Piping', 'Hand back area South of Condenser to Civil Contractor', 'Equipment Delivery by Siemens - MV Switchgear BBA', 'Equipment Delivery by Siemens - LV/DC Switchgear BFA', 'Equipment Delivery by Siemens - Cabinets for I&C 10UBA Building', 'Equipment Delivery by Siemens - Econopac fire Protection System CYE/ SGJ', 'Equipment Delivery by Siemens - ST MA- (LP-ROTOR, INNERCASING)', 'Equipment Delivery by Siemens - STEAM TURBINE MA- (HP/IP) (incl. FCA)', 'Equipment Delivery by Siemens - STEAM TURBINE MA- (HP/IP) EX WORKS', 'Equipment Delivery by Siemens - ST MA- (LP OUTER CASING)', 'Equipment Delivery by Siemens - ST GLAND STEAM CONDENSER MAW', 'Equipment Delivery by Siemens - EMERGENCY DIESEL GENERATOR SET XKA', 'Equipment Delivery by Siemens - Lighting Fixture', 'Equipment Delivery by Siemens - SEE TRANSFORMER MKC / SFC TRANSFORMER MBJ', 'Equipment Delivery by Siemens - TELECOMMUNICATION CYA', 'Equipment Delivery by Siemens - Batteries, Battery Charger, Converter & Inverter and UPS System', 'Equipment Delivery by Siemens - Filter House System', 'Equipment Delivery by Siemens - Condenser Tube Cleaning System PAH/PCH', 'Equipment Delivery by Siemens - Cathodic Corrosion Protection System', 'Equipment Delivery by Siemens - Central Control Room Furniture and Equipment', 'Equipment Delivery by Siemens - Continuous Emission Monitoring System Equipment', 'Equipment Delivery by Siemens - Electrical, Control & Instrumentation (for Gas Turbine & Auxiliaries)', 'Equipment Delivery by Siemens - Electrical, Control & Instrumentation (for HRSG)', 'Equipment Delivery by Siemens - Electrical, Control & Instrumentation (for Generator Steam Turbine)', 'Equipment Delivery by Siemens - Electrical, Control & Instrumentation (for BOP)', 'Equipment Purchasing - Switchboard of fuel oil system', 'Equipment Purchasing - Switchboard of reserved feed water system', 'Equipment Delivery UMC Crane', 'Equip Delivery - Feedwater Pumps LAC', 'Equipment Delivery by Siemens - Generator MK', 'Equipment Delivery by Siemens - Generator Skids MKA', 'Equipment Delivery by Siemens - Main Transformer BAT', 'Equipment Delivery by Siemens - Gas Turbine MB', 'Equipment Delivery by Siemens - HRSG Modules', 'Equipment Delivery by Siemens - Steam Condenser MAG', 'Equipment Delivery by Siemens - Gas Turbine Auxiliaries MB', 'Equipment Delivery by Siemens - GT Air Intake System MBL', 'Equipment Delivery by Siemens - GT Enclosure Incl. Ventilation MPB/SAM', 'Equipment Delivery by Siemens - Steam Turbine MA- (HP/IP) AUX. (Incl. FCA)', 'Equipment Delivery by Siemens - Steam Turbine Bearings MAD', 'Equipment Delivery by Siemens - ST Lube oil Module MAV', 'Equipment Delivery by Siemens - ST Hydraulic System MAX', 'Equipment Delivery by Siemens - Cooling Water Bar Screen for PAB System', 'Equipment Delivery by Siemens - Condenser Tube Cleaning System PAH - Module UPY00Y', 'Equipment Delivery by Siemens - Drums of HRSG', 'Equipment Delivery by Siemens - Piping Material HRSG', 'Equipment Delivery by Siemens - Main Steel Structure HRSG', 'Equipment Delivery by Siemens - Steam Turbine Drain Skid MAL00Y Module', 'Equipment Delivery by Siemens - Module Pipe Rack UMCM1Y', 'Equipment Delivery by Siemens - Module Pipe Rack UMCL1Y', 'Equipment Delivery by Siemens - Supply Piping DN >=80', 'Equipment Delivery by Siemens - Supply Piping DN <80', 'Equipment Delivery by Siemens - Main Transformer BBT', 'Equipment Delivery by Siemens - Isolated Generator Busduct 10BAA', 'Equipment Delivery by Siemens - LV Transformer BFT', 'Equipmen ...

# %% [markdown]
# ## Finish

# %%
finish_ms = list(companies_df['activity_name'][companies_df['activity_type']=='TT_FinMile'].unique())
print('finish milestones:', finish_ms)
# Out:
# finish milestones: ['Post TB2 P/L', 'MARK-UPS FROM SITE AVAILABLE', 'FINAL OPERATING AND MAINTENANCE DOCUMENTATION (O&M)', '(BOP6) COMPLETION AND SIGN OFF OF ALL CHECK SHEET TO CONFIRM COMPLETION OF HOT COMMISSIONING', '(6c) COMPLETION AND SIGN OFF OF ALL CHECK SHEET TO CONFIRM COMPLETION OF HOT COMMISSIONING', '(6e) COMPLETION OF AS-BUILT DRAWINGS AND OTHER COMPLETION DOCUMENTS', '(6d) COMPLETION OF O&M MANUALS', 'Handover of TOP 10MBP', 'Handover of TOP 10MBU-01', 'Handover of TOP 10BF-02', 'Handover of TOP 10CR-01', 'Handover of TOP 10CR-02', 'Handover of TOP-10CR-01', 'Handover of TOP-10CR-02', 'Handover of TOP 10SAM30', 'Back Engergization Achieved', 'Handover of TOP 10CKA', 'Handover of TOP 10MKC', 'Handover of TOP 10CJT', 'Handover of TOP 10BBT', 'Handover of TOP 10BA-02', 'Handover of TOP 10BA-01', 'Handover of TOP 10CHA', 'Handover of TOP 10BAT', 'Handover of TOP 10BF-01', 'Handover of TOP-10BF-01', 'LV Board ready for energisation via BMT01', 'BMT01 Energized', 'Handover of TOP 10BHV-01', 'Handover of TOP 10BFT-02', 'Handover of TOP 10BFT-03', 'Handover of TOP 10BFT-01', 'Handover of TOP 10CP-BOP-01', 'Handover of TOP 10BBA', 'Energisation of BMT01', 'Handover of TOP 10BT-01', 'Handover of TOP 10QFB-03', 'Handover of TOP 10QFB-02', 'Handover of TOP 10QFB-01', 'Handover of TOP 10LAB', 'Handover of TOP 10LCA', 'Handover of TOP 10SCB', 'Handover of TOP 00SCB', 'Handover of TOP 10MAX', 'Handover of TOP 10MKF', 'Handover of 10MBX2x', 'Handover of TOP 10MBA', 'Handover of TOP 10MBV', 'Handover of TOP 10MBX', 'Handover of TOP 10CP-GT', 'Handover of TOP 10MAW', 'Handover of TOP 10MAD', 'Handover of TOP 10MAV-01', 'Handover of TOP 10MAV-02', 'Handover of TOP 10MAV-03', 'Handover of TOP 10-CP-ST', 'Handover of TOP 10PGB', 'Handover of TOP-10GHC-01', 'Handover of TOP-10GHC-02', 'Handover of TOP-10GHC-03', 'Assumption Civil Contractor L&SP Complete', 'Assumption Underground Grid Complete', 'Ready for Energization from Temp. Feed', 'Assumption Underground System Available', 'Service Cooling Water Pumps Installed w/PXB00Y Module (See Activity 10PGB1010)', 'Inspections, Electrical Installations & Tests Begin', 'Release for Bus Bar Interface at the Terminal Bushing', 'Release for Coupling of the Gas Turbine', 'Checking Instrumentaion and Commissioning Seal Oil System Begin', 'Release for Connection of Piping to The Generator', 'Civil Contractor H/O West Side of HRSG back', 'Punchlist & Final Completion of HRSG Foundation Works - Prepare Pockets for GL11 Sole Plates', 'Civil Contractor H/O Inlet Duct Foundation', 'Generator in Position - Interface Date', 'Turbine Hall Grid Line 8-10 made available by Civil Contractor', 'Lube Oil System Ready for Flushing', 'Power Available for Oil Flushing', 'Foundations for HRSG', 'Turboset Foundation (UMC) (Completion of Foundatio Repair)', 'B7 - Construct Pile Caps, Tie Beams& GF Slab of Turbine Hall Building', 'C6 - Construct Foundations & Plinths for Support Steel for A/G Sections of CWP South of T/H', 'C3 - Construct Polishing Pit, G/F Slab for Condensate Polishing Plant area of T/H', 'E5 - Complete Foundations & Plinths for Chemical Unloading Bay, Urea StorageTank, Ammonia,', 'B2 - Construct Duct Bank Underneath the Diffuser', 'B5 - Construct Condensate Pit', 'B1 - Complete Foundation Structures and Pile Caps for Stack, Diffuser and HRSG Main Plant with Lift and Staircase', 'B3 - Construct temp.pad foundation for heavy lift crane & temp.H/O Area1a for M&E Contractor (Test Complete by KSS)', 'B6 - Construct Turboset foundation and supporting pile cap (Completion of Foundation Repair by Civil Contractor)', 'C7 - Complete ALL civil works incl. foundations, pile cap, blast walls & hard standings for Generator Transformer Area', 'C2 - Complete ALL building works incl. roof & cladding surrounding & above Turboset main equipment area', 'C4 - Install and T&C two 250t O/H cranes within Turbine Hall and H/O to M&E Contractor', 'D5 - Construct Boiler Blow Down Pit', 'D6 - Complete foundations and plinths ...

# %% [markdown]
# # WBS (Work Breakdown Structure)

# %%
wbs_names = list(companies_df['activity_name'][companies_df['activity_type']=='WBS'].unique())
print('WBS:', wbs_names)
# Out:
# WBS: ['CCGT D1_Integrated Programme Schedule', 'EWC - Early Civil Works', 'Construction', 'Piling Works for Power Island (Turbine Hall and HRSG)', 'Warehouse partial demolition works and A&A Works', 'Site Preparation, Advance Works and Piling Works', 'Statutory Submissions', 'BD Review and Approval', 'Design / Submission Preparation', 'Warehouse partial demolition and A&A Works', 'Advance works and site formation', 'Excavation', '(OEM) Commissioning', 'POST COMMISSIONING DELIVERABLES', 'POST TB2 P/L', 'DOCUMENTATION', 'SDS - Software Deliverable Schedule', 'Software Deliverables Construction/ Commissioning', 'Operation & Maintenance Manuals', 'MILESTONE', 'BOP Option_Key Dates / Contract Schedule 3A (Programme Requirements & Constraints)', 'Key Dates / Contract Schedule 3A (Programme Requirements & Constraints)', 'COLD COMMISSIONING', 'CLP System', '10CHA', '10EK', '10ZTA', '10EGC', '10EG', '10QJA', '10GHD', '10SGA', '10BAT', 'All System', 'LCAL MEP System', 'Balance of Systems for First Fire', '10QCC', '10QCD', '10ALL', '10PAB', '10PAA', '10SGC12-14', '10AUX B', '10LXX', '10HXX', '10TOP', '10MKA', '10MKW', '10MKG', '10MAG', '10LBG', '10LDK', '10LCL', '10LCB', '10LAC', '10GM', '10XKA', '10BAA', '10CPC91/92', '10ACA', '10MBP GT Fuel Gas System', '10MBU-01 Reserve Feedwater Pumps and Distribution System', '10BF-02 LV Switchgear BFB/BFC', '10CR Control Room Equipment', 'Fire Fighting Systems', '10SAM30 HVAC System for GT Noise Enclosure MPB', 'Circulating / Cooling Water System', 'Electrical', '400 kV Back Energization', 'Back Energization', '10CKA Partial discharge & shaft voltage / current monitoring system', '10MKC SEE / SFC Transformers', '10 CJT SEE / SFC Equipment', '10BBT Transformer 10BBT', '10BA-02 Isolated Phase Busduct Section BAC-MKA', '10BA-01 Isolated phase Busduct Section BAT-BAC', '10CHA Generator and Unit Transformer Protection', '10BAT Transformer BAT01', '10BF-01 LV Switchgear 10BFA / BMA / BLA', '6.6 kV (MV) Available (Station Power)', '(LCAL) LV Transformer', '10BHV-01 LVvTransformer BFT04 / BFT05 (BHV-01)', '(Siemens) LV Transformers', '10BFT-02 LV Transformer BFT02', '10BFT-03 LV Transformer BFT03', '10BFT-01 LV Transformer BFT01', '10CP-BOP-01 CPC Interface Panels ET200 in Function Area BOP (UBA Area)', '10BBA MV Distribution Switchgear BBA / BBB', 'DC Power Available', '10BT Battery Systems', 'Mechanical', 'EG Fuel Oil System', 'EK Fuel Gas System', 'Chemical Clean', 'Systems for Chem Clean', '10QFB Instrument Air Distribution system', '10QFB-03', '10QFB-02', '10QFB-01', '10LAB Feedwater system', '10LCA Main Condensate Supply & Preheating System', 'SCA / SCB Compressed Air System', '10MAX ST Hydraulic System', 'Turboset Turning Gear', 'Generator Ready for First Fire', '10MKF Generator Primary Water Cooling System', 'Generator Leak Test', 'Gas Turbine on Turning Gear', '10MBX2x GT Pneumatic System', '10MBA Gas Turbine Sysstem', '10MBV GT Lube Oil / Lifting Oil System', '10MBX GT Hydraulic Oil System', '10CP-GT Interface Panels ET200 in Function Area Gas Turbine', 'Steam Turbine on Turning Gear', '10MAW ST Seal Steam System', '10MAD ST Bearing System', '10MAV ST Lube and Lifting Oil System', '10CP-ST Interface Panels ET200 in Function Area Steam Turbine', 'PGB', '10PGB Closed Cooling Water System', 'Demin Water', 'Demin Water Distribution', 'Demin Water for Construction', 'CNY Outage & Fuel Availability', 'All Required Outstanding Construction & Cold Commissioning Activities for FF', 'Construction Completion Readiness of Chemical Clean', 'First Fire Readiness Reviews', 'Chemical Cleaning Commissioning Activities', 'Outage - Restoration [Affected Component List / Reinstatement] (Detail still to develop)', 'Restoration (Construction Works)', 'Siemens Works', 'HC - Hot Commissioing', 'Operation', 'Prepare Handover for TB2 Outage', 'Start F/ Oil Commissioning', 'Siemens culpibility for SCR Defect Rectification Wrks-19days Dur deduct fr the 90D correction period', 'Contractual Fuel Oil Commissioning and Performa ...

# %% [markdown]
# # Projects Names

# %%
companies = list(companies_df['company'].unique())
print('Companies in dataset:', companies)
for company in companies:
    project_names = list(companies_df['project_name'][companies_df['company']==company].unique())
    project_names = [p for p in project_names if str(p)!='nan']
    print(90*'-')
    print(print('Company: {c}'.format(c=str(company))))
    print('Projects:', ','.join(project_names))
# Out:
# Companies in dataset: ['CCGT_D1', 'CCGT_D2', 'DGDA_DG2', 'DUKE_S2X1CC', 'DUKE_WAYNE_COUNTY', 'SIME_DARBY_TASKS']
# ------------------------------------------------------------------------------------------
# Company: CCGT_D1
# None
# Projects: CCGTD1_IPS
# ------------------------------------------------------------------------------------------
# Company: CCGT_D2
# None
# Projects: HK1003-Rev.0E-3
# ------------------------------------------------------------------------------------------
# Company: DGDA_DG2
# None
# Projects: GMOQ-6,OPRA-1,SAMO-1,ICONH,KSU01,EW01,ARENA,INF01,KKR01,MP001-1,STAGE04,STAGE03,STAGE02,STAGE01
# ------------------------------------------------------------------------------------------
# Company: DUKE_S2X1CC
# None
# Projects: SCC Restore Outage,SP-PGN SU_R0 2-2,SP-PGN Start-up_R0 2,SP-ENG-MASTER-15,SP-CONST-MASTER-15
# ------------------------------------------------------------------------------------------
# Company: DUKE_WAYNE_COUNTY
# None
# Projects: WCCCP,WCCCP- PGN-SU,TOFRAG,STG,WCEP 100901 LVL1,WCCC Permit,WC - EP - MASTER
# ------------------------------------------------------------------------------------------
# Company: SIME_DARBY_TASKS
# None
# Projects:
