# %%
import os
import stanza
import spacy
stanza_nlp = stanza.Pipeline(lang="en")
spacy_nlp = spacy.load("en_core_web_lg")
# Out:
# 2022-01-20 12:21:51 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-01-20 12:21:51 INFO: Use device: cpu
# 2022-01-20 12:21:51 INFO: Loading: tokenize
# 2022-01-20 12:21:51 INFO: Loading: pos
# 2022-01-20 12:21:51 INFO: Loading: lemma
# 2022-01-20 12:21:51 INFO: Loading: depparse
# 2022-01-20 12:21:52 INFO: Loading: sentiment
# 2022-01-20 12:21:52 INFO: Loading: constituency
# 2022-01-20 12:21:52 INFO: Loading: ner
# 2022-01-20 12:21:53 INFO: Done loading processors!

# %%
results_dir = 'C:\\Users\\RonyArmon\\Projects_Code\\Cluster_Activities\\results'
names = open(os.path.join(results_dir,'names.txt')).read().split('\n')
names = names[:10]

# %%
def print_pos(sentence):
    print('name:', sentence)
    print('spacy:')
    doc = spacy_nlp(sentence)
    print(f"{'token':{8}} {'POS':{6}} {'TAG':{6}} {'Dep':{6}} {'POS explained':{20}} {'tag explained'} ")
    for token in doc:
        print(f'{token.text:{8}} {token.pos_:{6}}\
        {token.tag_:{6}} {token.dep_:{6}} {spacy.explain(token.pos_):{20}} {spacy.explain(token.tag_)}')
    print('stanza:')
    doc = stanza_nlp(sentence)
    print(*[f'{word.text}\t{word.upos}\t{word.xpos}\tdeprel: {word.deprel}\tfeats:\
    {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
#     print (30*'*')
#     comparison = input('comparison:')
    print (30*'*')

# %%
for name in names:
    print_pos(name)
# Out:
# name: construct trials & test for bd inspection and acknowledgement
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# construct VERB          VB     ROOT   verb                 verb, base form
# trials   NOUN          NNS    dobj   noun                 noun, plural
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# test     NOUN          NN     conj   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# bd       NOUN          NN     compound noun                 noun, singular or mass
# inspection NOUN          NN     pobj   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# acknowledgement NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# construct	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# trials	NOUN	NNS	deprel: obj	feats:    Number=Plur
# &	CCONJ	CC	deprel: cc	feats:    _
# test	NOUN	NN	deprel: conj	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# inspection	NOUN	NN	deprel: obl	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# acknowledgement	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: turbine hall (driven piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# turbine  PROPN         NNP    compound proper noun          noun, proper singular
# hall     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# driven   VERB          VBN    amod   verb                 verb, past participle
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# turbine	NOUN	NN	deprel: compound	feats:    Number=Sing
# hall	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# driven	VERB	VBN	deprel: amod	feats:    Tense=Past|VerbForm=Part
# piles	NOUN	NNS	deprel: appos	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: site drainage a&a works & site demob
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# site     NOUN          NN     compound noun                 noun, singular or mass
# drainage NOUN          NN     ROOT   noun                 noun, singular or mass
# a&a      PROPN         NNP    nmod   proper noun          noun, proper singular
# works    NOUN          NNS    appos  noun                 noun, plural
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# site     NOUN          NN     compound noun                 noun, singular or mass
# demob    NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# site	NOUN	NN	deprel: compound	feats:    Number=Sing
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# &	CCONJ	CC	deprel: cc	feats:    _
# site	NOUN	NN	deprel: conj	feats:    Number=Sing
# demob	PUNCT	.	deprel: punct	feats:    _
# ******************************
# name: turbine hall (pre-bore socket h-piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# turbine  PROPN         NNP    compound proper noun          noun, proper singular
# hall     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pre      ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# -        ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# bore     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# socket   NOUN          NN     compound noun                 noun, singular or mass
# h        NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# turbine	NOUN	NN	deprel: compound	feats:    Number=Sing
# hall	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pre-bore	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# socket	NOUN	NN	deprel: compound	feats:    Number=Sing
# h-piles	NOUN	NNS	deprel: appos	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: hrsg (driven h-piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# hrsg     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# driven   VERB          VBN    amod   verb                 verb, past participle
# h        NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# hrsg	PROPN	NNP	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# driven	VERB	VBN	deprel: parataxis	feats:    Tense=Past|VerbForm=Part
# h-piles	NOUN	NNS	deprel: xcomp	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: post drilling / bd selection / load tests / bd consent for pile cap
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# post     VERB          VB     nmod   verb                 verb, base form
# drilling NOUN          NN     nmod   noun                 noun, singular or mass
# /        SYM           SYM    punct  symbol               symbol
# bd       NOUN          NN     conj   noun                 noun, singular or mass
# selection NOUN          NN     nmod   noun                 noun, singular or mass
# /        SYM           SYM    punct  symbol               symbol
# load     NOUN          NN     compound noun                 noun, singular or mass
# tests    NOUN          NNS    dobj   noun                 noun, plural
# /        SYM           SYM    punct  symbol               symbol
# bd       NOUN          NN     compound noun                 noun, singular or mass
# consent  NOUN          NN     ROOT   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# pile     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# cap      NOUN          NN     pobj   noun                 noun, singular or mass
# stanza:
# post	NOUN	NN	deprel: compound	feats:    Number=Sing
# drilling	NOUN	NN	deprel: compound	feats:    Number=Sing
# /	SYM	,	deprel: punct	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# selection	NOUN	NN	deprel: root	feats:    Number=Sing
# /	SYM	,	deprel: cc	feats:    _
# load	NOUN	NN	deprel: compound	feats:    Number=Sing
# tests	NOUN	NNS	deprel: conj	feats:    Number=Plur
# /	SYM	,	deprel: cc	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# consent	NOUN	NN	deprel: conj	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# pile	NOUN	NN	deprel: compound	feats:    Number=Sing
# cap	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: warehouse demolition works
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     nsubj  noun                 noun, singular or mass
# works    VERB          VBZ    ROOT   verb                 verb, 3rd person singular present
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# ******************************
# name: warehouse a&a works, ready for main contract fitout (150 days - 14/5/2017)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     ROOT   noun                 noun, singular or mass
# a&a      PROPN         NNP    compound proper noun          noun, proper singular
# works    VERB          VBZ    dobj   verb                 verb, 3rd person singular present
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# ready    ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# main     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# contract NOUN          NN     compound noun                 noun, singular or mass
# fitout   NOUN          NN     pobj   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# 150      NUM           CD     nummod numeral              cardinal number
# days     NOUN          NNS    appos  noun                 noun, plural
# -        PUNCT         :      punct  punctuation          punctuation mark, colon or ellipsis
# 14/5/2017 NUM           CD     appos  numeral              cardinal number
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# ,	PUNCT	,	deprel: punct	feats:    _
# ready	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# for	ADP	IN	deprel: case	feats:    _
# main	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# contract	NOUN	NN	deprel: compound	feats:    Number=Sing
# fitout	NOUN	NN	deprel: obl	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# 150	NUM	CD	deprel: nummod	feats:    NumType=Card
# days	NOUN	NNS	deprel: appos	feats:    Number=Plur
# -	SYM	SYM	deprel: case	feats:    _
# 14/5/2017	NUM	CD	deprel: nmod	feats:    NumType=Card
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: power island piling - 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     compound noun                 noun, singular or mass
# piling   NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# 1st      NOUN          NN     amod   noun                 noun, singular or mass
# submission NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: root	feats:    Number=Sing
# piling	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# ******************************
# name: power island piling - amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     compound noun                 noun, singular or mass
# piling   NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# amendment NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: compound	feats:    Number=Sing
# piling	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# amendment	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
