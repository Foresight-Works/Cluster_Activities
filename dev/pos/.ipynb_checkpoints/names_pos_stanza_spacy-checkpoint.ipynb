# %%
import os
import stanza
import spacy
stanza_nlp = stanza.Pipeline(lang="en")
spacy_nlp = spacy.load("en_core_web_lg")
# Out:
# 2022-01-20 12:21:51 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-01-20 12:21:51 INFO: Use device: cpu
# 2022-01-20 12:21:51 INFO: Loading: tokenize
# 2022-01-20 12:21:51 INFO: Loading: pos
# 2022-01-20 12:21:51 INFO: Loading: lemma
# 2022-01-20 12:21:51 INFO: Loading: depparse
# 2022-01-20 12:21:52 INFO: Loading: sentiment
# 2022-01-20 12:21:52 INFO: Loading: constituency
# 2022-01-20 12:21:52 INFO: Loading: ner
# 2022-01-20 12:21:53 INFO: Done loading processors!

# %%
results_dir = 'C:\\Users\\RonyArmon\\Projects_Code\\Cluster_Activities\\results'
names = open(os.path.join(results_dir,'names.txt')).read().split('\n')
names = names[:10]
# Out:
# 'construct trials & test for bd inspection and acknowledgement'

# %%
def print_pos(sentence):
    print('name:', sentence)
    print('spacy:')
    doc = spacy_nlp(sentence)
    print(f"{'token':{8}} {'POS':{6}} {'TAG':{6}} {'Dep':{6}} {'POS explained':{20}} {'tag explained'} ")
    for token in doc:
        print(f'{token.text:{8}} {token.pos_:{6}}\
        {token.tag_:{6}} {token.dep_:{6}} {spacy.explain(token.pos_):{20}} {spacy.explain(token.tag_)}')
    print('stanza:')
    doc = stanza_nlp(sentence)
    print(*[f'{word.text}\t{word.upos}\t{word.xpos}\tdeprel: {word.deprel}\tfeats:\
    {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
#     print (30*'*')
#     comparison = input('comparison:')
    print (30*'*')

# %%
for name in names:
    print_pos(name)
# Out:
# name: construct trials & test for bd inspection and acknowledgement
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# construct VERB          VB     ROOT   verb                 verb, base form
# trials   NOUN          NNS    dobj   noun                 noun, plural
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# test     NOUN          NN     conj   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# bd       NOUN          NN     compound noun                 noun, singular or mass
# inspection NOUN          NN     pobj   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# acknowledgement NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# construct	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# trials	NOUN	NNS	deprel: obj	feats:    Number=Plur
# &	CCONJ	CC	deprel: cc	feats:    _
# test	NOUN	NN	deprel: conj	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# inspection	NOUN	NN	deprel: obl	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# acknowledgement	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: turbine hall (driven piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# turbine  PROPN         NNP    compound proper noun          noun, proper singular
# hall     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# driven   VERB          VBN    amod   verb                 verb, past participle
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# turbine	NOUN	NN	deprel: compound	feats:    Number=Sing
# hall	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# driven	VERB	VBN	deprel: amod	feats:    Tense=Past|VerbForm=Part
# piles	NOUN	NNS	deprel: appos	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: site drainage a&a works & site demob
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# site     NOUN          NN     compound noun                 noun, singular or mass
# drainage NOUN          NN     ROOT   noun                 noun, singular or mass
# a&a      PROPN         NNP    nmod   proper noun          noun, proper singular
# works    NOUN          NNS    appos  noun                 noun, plural
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# site     NOUN          NN     compound noun                 noun, singular or mass
# demob    NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# site	NOUN	NN	deprel: compound	feats:    Number=Sing
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# &	CCONJ	CC	deprel: cc	feats:    _
# site	NOUN	NN	deprel: conj	feats:    Number=Sing
# demob	PUNCT	.	deprel: punct	feats:    _
# ******************************
# name: turbine hall (pre-bore socket h-piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# turbine  PROPN         NNP    compound proper noun          noun, proper singular
# hall     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pre      ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# -        ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# bore     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# socket   NOUN          NN     compound noun                 noun, singular or mass
# h        NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# turbine	NOUN	NN	deprel: compound	feats:    Number=Sing
# hall	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pre-bore	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# socket	NOUN	NN	deprel: compound	feats:    Number=Sing
# h-piles	NOUN	NNS	deprel: appos	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: hrsg (driven h-piles)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# hrsg     PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# driven   VERB          VBN    amod   verb                 verb, past participle
# h        NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# piles    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# hrsg	PROPN	NNP	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# driven	VERB	VBN	deprel: parataxis	feats:    Tense=Past|VerbForm=Part
# h-piles	NOUN	NNS	deprel: xcomp	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: post drilling / bd selection / load tests / bd consent for pile cap
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# post     VERB          VB     nmod   verb                 verb, base form
# drilling NOUN          NN     nmod   noun                 noun, singular or mass
# /        SYM           SYM    punct  symbol               symbol
# bd       NOUN          NN     conj   noun                 noun, singular or mass
# selection NOUN          NN     nmod   noun                 noun, singular or mass
# /        SYM           SYM    punct  symbol               symbol
# load     NOUN          NN     compound noun                 noun, singular or mass
# tests    NOUN          NNS    dobj   noun                 noun, plural
# /        SYM           SYM    punct  symbol               symbol
# bd       NOUN          NN     compound noun                 noun, singular or mass
# consent  NOUN          NN     ROOT   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# pile     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# cap      NOUN          NN     pobj   noun                 noun, singular or mass
# stanza:
# post	NOUN	NN	deprel: compound	feats:    Number=Sing
# drilling	NOUN	NN	deprel: compound	feats:    Number=Sing
# /	SYM	,	deprel: punct	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# selection	NOUN	NN	deprel: root	feats:    Number=Sing
# /	SYM	,	deprel: cc	feats:    _
# load	NOUN	NN	deprel: compound	feats:    Number=Sing
# tests	NOUN	NNS	deprel: conj	feats:    Number=Plur
# /	SYM	,	deprel: cc	feats:    _
# bd	NOUN	NN	deprel: compound	feats:    Number=Sing
# consent	NOUN	NN	deprel: conj	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# pile	NOUN	NN	deprel: compound	feats:    Number=Sing
# cap	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: warehouse demolition works
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     nsubj  noun                 noun, singular or mass
# works    VERB          VBZ    ROOT   verb                 verb, 3rd person singular present
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# ******************************
# name: warehouse a&a works, ready for main contract fitout (150 days - 14/5/2017)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     ROOT   noun                 noun, singular or mass
# a&a      PROPN         NNP    compound proper noun          noun, proper singular
# works    VERB          VBZ    dobj   verb                 verb, 3rd person singular present
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# ready    ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# main     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# contract NOUN          NN     compound noun                 noun, singular or mass
# fitout   NOUN          NN     pobj   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# 150      NUM           CD     nummod numeral              cardinal number
# days     NOUN          NNS    appos  noun                 noun, plural
# -        PUNCT         :      punct  punctuation          punctuation mark, colon or ellipsis
# 14/5/2017 NUM           CD     appos  numeral              cardinal number
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: root	feats:    Number=Plur
# ,	PUNCT	,	deprel: punct	feats:    _
# ready	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# for	ADP	IN	deprel: case	feats:    _
# main	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# contract	NOUN	NN	deprel: compound	feats:    Number=Sing
# fitout	NOUN	NN	deprel: obl	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# 150	NUM	CD	deprel: nummod	feats:    NumType=Card
# days	NOUN	NNS	deprel: appos	feats:    Number=Plur
# -	SYM	SYM	deprel: case	feats:    _
# 14/5/2017	NUM	CD	deprel: nmod	feats:    NumType=Card
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: power island piling - 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     compound noun                 noun, singular or mass
# piling   NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# 1st      NOUN          NN     amod   noun                 noun, singular or mass
# submission NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: root	feats:    Number=Sing
# piling	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# ******************************
# name: power island piling - amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     compound noun                 noun, singular or mass
# piling   NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# amendment NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: compound	feats:    Number=Sing
# piling	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# amendment	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: ba14 submission & pile test
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# ba14     PROPN         NNP    nmod   proper noun          noun, proper singular
# submission NOUN          NN     nmod   noun                 noun, singular or mass
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# pile     NOUN          NN     conj   noun                 noun, singular or mass
# test     NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# ba14	NOUN	NN	deprel: compound	feats:    Number=Sing
# submission	NOUN	NN	deprel: root	feats:    Number=Sing
# &	CCONJ	CC	deprel: cc	feats:    _
# pile	NOUN	NN	deprel: compound	feats:    Number=Sing
# test	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: power island piling - consent
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     compound noun                 noun, singular or mass
# piling   NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# consent  NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: root	feats:    Number=Sing
# piling	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# consent	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# ******************************
# name: piling 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 1st      ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# submission NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: piling 1st  amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 1st      NOUN          NN     dobj   noun                 noun, singular or mass
#          SPACE         _SP    dep    space                whitespace
# amendment NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: piling 2nd amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 2nd      PROPN         NNP    compound proper noun          noun, proper singular
# amendment PROPN         NNP    dobj   proper noun          noun, proper singular
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 2nd	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: piling 3rd amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 3rd      PROPN         NNP    compound proper noun          noun, proper singular
# amendment NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 3rd	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: piling 4th amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 4th      PROPN         NNP    compound proper noun          noun, proper singular
# amendment NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 4th	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: piling 5th amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# piling   VERB          VBG    ROOT   verb                 verb, gerund or present participle
# 5th      ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# amendment NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# piling	VERB	VBG	deprel: root	feats:    VerbForm=Ger
# 5th	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: prepare power island piling submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# prepare  VERB          VB     ROOT   verb                 verb, base form
# power    NOUN          NN     compound noun                 noun, singular or mass
# island   NOUN          NN     nsubj  noun                 noun, singular or mass
# piling   VERB          VBG    ccomp  verb                 verb, gerund or present participle
# submission NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# prepare	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# power	NOUN	NN	deprel: compound	feats:    Number=Sing
# island	NOUN	NN	deprel: obj	feats:    Number=Sing
# piling	VERB	VBG	deprel: advcl	feats:    VerbForm=Ger
# submission	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: warehouse demolition and a&a works (gbp) - amendment submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     ROOT   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      PROPN         NNP    compound proper noun          noun, proper singular
# works    NOUN          NNS    conj   noun                 noun, plural
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# gbp      PROPN         NNP    appos  proper noun          noun, proper singular
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# -        PUNCT         :      punct  punctuation          punctuation mark, colon or ellipsis
# amendment NOUN          NN     compound noun                 noun, singular or mass
# submission NOUN          NN     appos  noun                 noun, singular or mass
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: root	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: conj	feats:    Number=Plur
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# gbp	NOUN	NN	deprel: appos	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# -	PUNCT	HYPH	deprel: punct	feats:    _
# amendment	NOUN	NN	deprel: compound	feats:    Number=Sing
# submission	NOUN	NN	deprel: appos	feats:    Number=Sing
# ******************************
# name: warehouse demolition and a&a works (gbp & structural) - 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     ROOT   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      PROPN         NNP    compound proper noun          noun, proper singular
# works    NOUN          NNS    conj   noun                 noun, plural
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# gbp      PROPN         NNP    appos  proper noun          noun, proper singular
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# structural PROPN         NNP    conj   proper noun          noun, proper singular
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# -        PUNCT         :      punct  punctuation          punctuation mark, colon or ellipsis
# 1st      ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# submission NOUN          NN     appos  noun                 noun, singular or mass
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: root	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: conj	feats:    Number=Plur
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# gbp	NOUN	NN	deprel: compound	feats:    Number=Sing
# &	CCONJ	CC	deprel: cc	feats:    _
# structural	ADJ	JJ	deprel: conj	feats:    Degree=Pos
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# -	PUNCT	HYPH	deprel: punct	feats:    _
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# ******************************
# name: warehouse demolition and a&a works - consent
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     ROOT   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      ADJ           JJ     compound adjective            adjective (English), other noun-modifier (Chinese)
# works    NOUN          NNS    compound noun                 noun, plural
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# consent  NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: root	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: conj	feats:    Number=Plur
# -	PUNCT	,	deprel: punct	feats:    _
# consent	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# ******************************
# name: warehouse demolition and a&a works (structural)- amendment submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     ROOT   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      ADJ           JJ     compound adjective            adjective (English), other noun-modifier (Chinese)
# works    NOUN          NNS    conj   noun                 noun, plural
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# structural)- NOUN          NN     compound noun                 noun, singular or mass
# amendment NOUN          NN     compound noun                 noun, singular or mass
# submission NOUN          NN     appos  noun                 noun, singular or mass
# stanza:
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: root	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: conj	feats:    Number=Plur
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# structural	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# -	PUNCT	HYPH	deprel: punct	feats:    _
# amendment	NOUN	NN	deprel: compound	feats:    Number=Sing
# submission	NOUN	NN	deprel: appos	feats:    Number=Sing
# ******************************
# name: prepare warehouse demolition and a&a works amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# prepare  VERB          VB     ROOT   verb                 verb, base form
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     dobj   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      PROPN         NNP    compound proper noun          noun, proper singular
# works    NOUN          NNS    compound noun                 noun, plural
# amendment NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# prepare	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: compound	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: compound	feats:    Number=Plur
# amendment	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: prepare warehouse demolition and a&a works
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# prepare  VERB          VB     ROOT   verb                 verb, base form
# warehouse NOUN          NN     compound noun                 noun, singular or mass
# demolition NOUN          NN     dobj   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# a&a      PROPN         NNP    nsubj  proper noun          noun, proper singular
# works    VERB          VBZ    conj   verb                 verb, 3rd person singular present
# stanza:
# prepare	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# warehouse	NOUN	NN	deprel: compound	feats:    Number=Sing
# demolition	NOUN	NN	deprel: obj	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# a&a	NOUN	NN	deprel: compound	feats:    Number=Sing
# works	NOUN	NNS	deprel: obj	feats:    Number=Plur
# ******************************
# name: drainage diversion 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# 1st      NOUN          NN     compound noun                 noun, singular or mass
# submission NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: root	feats:    Number=Sing
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: drainage diversion gbp
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# gbp      NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# gbp	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: drainage diversion - consent
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# consent  NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# -	PUNCT	HYPH	deprel: punct	feats:    _
# consent	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: drainage diversion resubmission (structural)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# resubmission NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# structural ADJ           JJ     appos  adjective            adjective (English), other noun-modifier (Chinese)
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# resubmission	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# structural	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: drainage diversion resubmission (drainage plans)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# resubmission NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# drainage NOUN          NN     compound noun                 noun, singular or mass
# plans    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# resubmission	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# plans	NOUN	NNS	deprel: parataxis	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: drainage diversion 1st amendment (structural)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# 1st      PROPN         NNP    compound proper noun          noun, proper singular
# amendment PROPN         NNP    ROOT   proper noun          noun, proper singular
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# structural ADJ           JJ     appos  adjective            adjective (English), other noun-modifier (Chinese)
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# structural	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: drainage diversion els 1st submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# els      NOUN          NNS    compound noun                 noun, plural
# 1st      PROPN         NNP    compound proper noun          noun, proper singular
# submission NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: root	feats:    Number=Sing
# els	NOUN	NN	deprel: appos	feats:    Number=Sing
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# submission	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: drainage diversion els 1st amendment
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# els      NOUN          NNS    compound noun                 noun, plural
# 1st      PROPN         NNP    compound proper noun          noun, proper singular
# amendment PROPN         NNP    ROOT   proper noun          noun, proper singular
# stanza:
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: root	feats:    Number=Sing
# els	NOUN	NN	deprel: appos	feats:    Number=Sing
# 1st	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# amendment	NOUN	NN	deprel: conj	feats:    Number=Sing
# ******************************
# name: prepare drainage diversion submission
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# prepare  VERB          VB     ROOT   verb                 verb, base form
# drainage NOUN          NN     compound noun                 noun, singular or mass
# diversion NOUN          NN     compound noun                 noun, singular or mass
# submission NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# prepare	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# drainage	NOUN	NN	deprel: compound	feats:    Number=Sing
# diversion	NOUN	NN	deprel: compound	feats:    Number=Sing
# submission	NOUN	NN	deprel: obj	feats:    Number=Sing
# ******************************
# name: bulk excavation
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# bulk     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# excavation NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# bulk	NOUN	NN	deprel: compound	feats:    Number=Sing
# excavation	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: primary protection test discussion
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# primary  ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# protection NOUN          NN     compound noun                 noun, singular or mass
# test     NOUN          NN     compound noun                 noun, singular or mass
# discussion NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# primary	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# protection	NOUN	NN	deprel: compound	feats:    Number=Sing
# test	NOUN	NN	deprel: compound	feats:    Number=Sing
# discussion	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: ek purging procedure review
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# ek       PROPN         NNP    npadvmod proper noun          noun, proper singular
# purging  VERB          VBG    ROOT   verb                 verb, gerund or present participle
# procedure NOUN          NN     compound noun                 noun, singular or mass
# review   NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# ek	NOUN	NN	deprel: compound	feats:    Number=Sing
# purging	VERB	VBG	deprel: amod	feats:    VerbForm=Ger
# procedure	NOUN	NN	deprel: compound	feats:    Number=Sing
# review	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: chemical clean effluent coordination
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# chemical PROPN         NNP    npadvmod proper noun          noun, proper singular
# clean    PROPN         NNP    compound proper noun          noun, proper singular
# effluent ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# coordination NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# chemical	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# clean	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# effluent	NOUN	NN	deprel: compound	feats:    Number=Sing
# coordination	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: rotation checks & motor solo runs for fuel oil forwarding pumps
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# rotation PROPN         NNP    compound proper noun          noun, proper singular
# checks   NOUN          NNS    ROOT   noun                 noun, plural
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# motor    NOUN          NN     compound noun                 noun, singular or mass
# solo     NOUN          NN     compound noun                 noun, singular or mass
# runs     VERB          VBZ    conj   verb                 verb, 3rd person singular present
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# fuel     NOUN          NN     compound noun                 noun, singular or mass
# oil      NOUN          NN     compound noun                 noun, singular or mass
# forwarding NOUN          NN     compound noun                 noun, singular or mass
# pumps    VERB          VBZ    pobj   verb                 verb, 3rd person singular present
# stanza:
# rotation	NOUN	NN	deprel: compound	feats:    Number=Sing
# checks	NOUN	NNS	deprel: root	feats:    Number=Plur
# &	CCONJ	CC	deprel: cc	feats:    _
# motor	NOUN	NN	deprel: compound	feats:    Number=Sing
# solo	NOUN	NN	deprel: compound	feats:    Number=Sing
# runs	NOUN	NNS	deprel: conj	feats:    Number=Plur
# for	ADP	IN	deprel: case	feats:    _
# fuel	NOUN	NN	deprel: compound	feats:    Number=Sing
# oil	NOUN	NN	deprel: compound	feats:    Number=Sing
# forwarding	NOUN	NN	deprel: compound	feats:    Number=Sing
# pumps	NOUN	NNS	deprel: nmod	feats:    Number=Plur
# ******************************
# name: eg tie-in work coordination
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# eg       ADP           IN     ROOT   adposition           conjunction, subordinating or preposition
# tie      NOUN          NN     nmod   noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# in       ADP           RP     prt    adposition           adverb, particle
# work     NOUN          NN     compound noun                 noun, singular or mass
# coordination NOUN          NN     pobj   noun                 noun, singular or mass
# stanza:
# eg	NOUN	NN	deprel: compound	feats:    Number=Sing
# tie-	NOUN	NN	deprel: root	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# work	NOUN	NN	deprel: compound	feats:    Number=Sing
# coordination	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: qja10 / qja20 tie-in work coordination
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# qja10    PROPN         NNP    nmod   proper noun          noun, proper singular
# /        SYM           SYM    punct  symbol               symbol
# qja20    PROPN         NNP    compound proper noun          noun, proper singular
# tie      NOUN          NN     amod   noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# in       ADP           RP     prt    adposition           adverb, particle
# work     NOUN          NN     compound noun                 noun, singular or mass
# coordination NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# qja10	NOUN	NN	deprel: compound	feats:    Number=Sing
# /	PUNCT	,	deprel: punct	feats:    _
# qja20	NOUN	NN	deprel: compound	feats:    Number=Sing
# tie-	NOUN	NN	deprel: root	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# work	NOUN	NN	deprel: compound	feats:    Number=Sing
# coordination	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: ghd tie-in work coordination
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# ghd      NOUN          NN     amod   noun                 noun, singular or mass
# tie      NOUN          NN     nmod   noun                 noun, singular or mass
# -        PUNCT         HYPH   punct  punctuation          punctuation mark, hyphen
# in       ADP           RP     prt    adposition           adverb, particle
# work     NOUN          NN     compound noun                 noun, singular or mass
# coordination NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# ghd	NOUN	NN	deprel: compound	feats:    Number=Sing
# tie-	NOUN	NN	deprel: root	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# work	NOUN	NN	deprel: compound	feats:    Number=Sing
# coordination	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: fresh water fire fight system preparation and spray test
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# fresh    ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# water    NOUN          NN     compound noun                 noun, singular or mass
# fire     NOUN          NN     compound noun                 noun, singular or mass
# fight    NOUN          NN     compound noun                 noun, singular or mass
# system   NOUN          NN     compound noun                 noun, singular or mass
# preparation NOUN          NN     ROOT   noun                 noun, singular or mass
# and      CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# spray    NOUN          NN     conj   noun                 noun, singular or mass
# test     NOUN          NN     conj   noun                 noun, singular or mass
# stanza:
# fresh	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# water	NOUN	NN	deprel: compound	feats:    Number=Sing
# fire	NOUN	NN	deprel: compound	feats:    Number=Sing
# fight	NOUN	NN	deprel: compound	feats:    Number=Sing
# system	NOUN	NN	deprel: compound	feats:    Number=Sing
# preparation	NOUN	NN	deprel: compound	feats:    Number=Sing
# and	CCONJ	CC	deprel: cc	feats:    _
# spray	NOUN	NN	deprel: compound	feats:    Number=Sing
# test	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: fire fighting system flushing coordination
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# fire     NOUN          NN     compound noun                 noun, singular or mass
# fighting NOUN          NN     compound noun                 noun, singular or mass
# system   NOUN          NN     nsubj  noun                 noun, singular or mass
# flushing VERB          VBG    ROOT   verb                 verb, gerund or present participle
# coordination NOUN          NN     dobj   noun                 noun, singular or mass
# stanza:
# fire	NOUN	NN	deprel: compound	feats:    Number=Sing
# fighting	NOUN	NN	deprel: compound	feats:    Number=Sing
# system	NOUN	NN	deprel: compound	feats:    Number=Sing
# flushing	NOUN	NN	deprel: compound	feats:    Number=Sing
# coordination	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: backfeed coordination (hv injection & interlock/intertrip tests)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# backfeed NOUN          NN     compound noun                 noun, singular or mass
# coordination NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# hv       PROPN         NNP    compound proper noun          noun, proper singular
# injection NOUN          NN     appos  noun                 noun, singular or mass
# &        CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# interlock NOUN          NN     nmod   noun                 noun, singular or mass
# /        SYM           SYM    punct  symbol               symbol
# intertrip NOUN          NN     conj   noun                 noun, singular or mass
# tests    NOUN          NNS    appos  noun                 noun, plural
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# backfeed	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# coordination	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# hv	NOUN	NN	deprel: compound	feats:    Number=Sing
# injection	NOUN	NN	deprel: compound	feats:    Number=Sing
# &	CCONJ	CC	deprel: cc	feats:    _
# interlock	NOUN	NN	deprel: conj	feats:    Number=Sing
# /	SYM	,	deprel: cc	feats:    _
# intertrip	NOUN	NN	deprel: compound	feats:    Number=Sing
# tests	NOUN	NNS	deprel: appos	feats:    Number=Plur
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: backfeed coordination (document review)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# backfeed NOUN          NN     compound noun                 noun, singular or mass
# coordination NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# document NOUN          NN     compound noun                 noun, singular or mass
# review   NOUN          NN     appos  noun                 noun, singular or mass
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# backfeed	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# coordination	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# document	NOUN	NN	deprel: compound	feats:    Number=Sing
# review	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: issue for bat re-energization after outage
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# issue    NOUN          NN     nsubj  noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# bat      NOUN          NN     pobj   noun                 noun, singular or mass
# re       NOUN          NN     ROOT   noun                 noun, singular or mass
# -        NOUN          NN     dobj   noun                 noun, singular or mass
# energization NOUN          NN     dobj   noun                 noun, singular or mass
# after    ADP           IN     prep   adposition           conjunction, subordinating or preposition
# outage   NOUN          NN     pobj   noun                 noun, singular or mass
# stanza:
# issue	NOUN	NN	deprel: root	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# bat	NOUN	NN	deprel: compound	feats:    Number=Sing
# re-energization	NOUN	NN	deprel: nmod	feats:    Number=Sing
# after	ADP	IN	deprel: case	feats:    _
# outage	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: transformer re-energization work
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# transformer NOUN          NN     compound noun                 noun, singular or mass
# re       NOUN          NN     amod   noun                 noun, singular or mass
# -        NOUN          NN     amod   noun                 noun, singular or mass
# energization ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# work     NOUN          NN     ROOT   noun                 noun, singular or mass
# stanza:
# transformer	NOUN	NN	deprel: compound	feats:    Number=Sing
# re-energization	NOUN	NN	deprel: compound	feats:    Number=Sing
# work	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: station interface walkdowns for all upcoming terminal points (flushing/cleaning preparation)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# station  NOUN          NN     compound noun                 noun, singular or mass
# interface NOUN          NN     compound noun                 noun, singular or mass
# ...
# commissioning	NOUN	NN	deprel: root	feats:    Number=Sing
# ******************************
# name: cold commissioning (pending top)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# cold     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# commissioning NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pending  VERB          VBG    amod   verb                 verb, gerund or present participle
# top      NOUN          NN     appos  noun                 noun, singular or mass
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# cold	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# commissioning	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pending	VERB	VBG	deprel: parataxis	feats:    VerbForm=Ger
# top	NOUN	NN	deprel: obj	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: cold commissioning incl motor solo runs incl first pump operation
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# cold     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# commissioning VERB          VBG    compound verb                 verb, gerund or present participle
# incl     PROPN         NNP    compound proper noun          noun, proper singular
# motor    NOUN          NN     compound noun                 noun, singular or mass
# solo     NOUN          NN     nsubj  noun                 noun, singular or mass
# runs     VERB          VBZ    ROOT   verb                 verb, 3rd person singular present
# incl     NOUN          NN     dobj   noun                 noun, singular or mass
# first    ADV           RB     amod   adverb               adverb
# pump     NOUN          NN     compound noun                 noun, singular or mass
# operation NOUN          NN     npadvmod noun                 noun, singular or mass
# stanza:
# cold	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# commissioning	NOUN	NN	deprel: compound	feats:    Number=Sing
# incl	NOUN	NN	deprel: compound	feats:    Number=Sing
# motor	NOUN	NN	deprel: compound	feats:    Number=Sing
# solo	NOUN	NN	deprel: nsubj	feats:    Number=Sing
# runs	VERB	VBZ	deprel: root	feats:    Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# incl	ADP	IN	deprel: case	feats:    _
# first	ADJ	JJ	deprel: amod	feats:    Degree=Pos|NumType=Ord
# pump	NOUN	NN	deprel: compound	feats:    Number=Sing
# operation	NOUN	NN	deprel: obl	feats:    Number=Sing
# ******************************
# name: system in service for flushing
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# system   NOUN          NN     ROOT   noun                 noun, singular or mass
# in       ADP           IN     prep   adposition           conjunction, subordinating or preposition
# service  NOUN          NN     pobj   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# flushing VERB          VBG    pcomp  verb                 verb, gerund or present participle
# stanza:
# system	NOUN	NN	deprel: root	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# service	NOUN	NN	deprel: nmod	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# flushing	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: system in service
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# system   NOUN          NN     ROOT   noun                 noun, singular or mass
# in       ADP           IN     prep   adposition           conjunction, subordinating or preposition
# service  NOUN          NN     pobj   noun                 noun, singular or mass
# stanza:
# system	NOUN	NN	deprel: root	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# service	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: min flow run (pending top)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# min      NOUN          NN     compound noun                 noun, singular or mass
# flow     NOUN          NN     compound noun                 noun, singular or mass
# run      NOUN          NN     ROOT   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pending  VERB          VBG    amod   verb                 verb, gerund or present participle
# top      NOUN          NN     appos  noun                 noun, singular or mass
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# min	NOUN	NN	deprel: compound	feats:    Number=Sing
# flow	NOUN	NN	deprel: compound	feats:    Number=Sing
# run	NOUN	NN	deprel: root	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pending	VERB	VBG	deprel: parataxis	feats:    VerbForm=Ger
# top	NOUN	NN	deprel: obj	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: preparation for min flow run, cold comissioning (pending top)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# preparation NOUN          NN     ROOT   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# min      NOUN          NN     compound noun                 noun, singular or mass
# flow     NOUN          NN     compound noun                 noun, singular or mass
# run      NOUN          NN     pobj   noun                 noun, singular or mass
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# cold     ADJ           JJ     compound adjective            adjective (English), other noun-modifier (Chinese)
# comissioning NOUN          NN     conj   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pending  VERB          VBG    amod   verb                 verb, gerund or present participle
# top      NOUN          NN     appos  noun                 noun, singular or mass
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# preparation	NOUN	NN	deprel: root	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# min	NOUN	NN	deprel: compound	feats:    Number=Sing
# flow	NOUN	NN	deprel: compound	feats:    Number=Sing
# run	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ,	PUNCT	,	deprel: punct	feats:    _
# cold	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# comissioning	NOUN	NN	deprel: parataxis	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pending	VERB	VBG	deprel: amod	feats:    VerbForm=Ger
# top	NOUN	NN	deprel: appos	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: pump operation for high velocity flushing
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# pump     VERB          VB     ROOT   verb                 verb, base form
# operation NOUN          NN     dobj   noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# high     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# velocity NOUN          NN     pobj   noun                 noun, singular or mass
# flushing VERB          VBG    pcomp  verb                 verb, gerund or present participle
# stanza:
# pump	NOUN	NN	deprel: compound	feats:    Number=Sing
# operation	NOUN	NN	deprel: root	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# high	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# velocity	NOUN	NN	deprel: compound	feats:    Number=Sing
# flushing	NOUN	NN	deprel: nmod	feats:    Number=Sing
# ******************************
# name: cold commissioning, preparation for oil flushing (pending top)
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# cold     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# commissioning NOUN          NN     ROOT   noun                 noun, singular or mass
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# preparation NOUN          NN     appos  noun                 noun, singular or mass
# for      ADP           IN     prep   adposition           conjunction, subordinating or preposition
# oil      NOUN          NN     compound noun                 noun, singular or mass
# flushing NOUN          NN     pobj   noun                 noun, singular or mass
# (        PUNCT         -LRB-  punct  punctuation          left round bracket
# pending  VERB          VBG    amod   verb                 verb, gerund or present participle
# top      NOUN          NN     appos  noun                 noun, singular or mass
# )        PUNCT         -RRB-  punct  punctuation          right round bracket
# stanza:
# cold	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# commissioning	NOUN	NN	deprel: root	feats:    Number=Sing
# ,	PUNCT	,	deprel: punct	feats:    _
# preparation	NOUN	NN	deprel: conj	feats:    Number=Sing
# for	ADP	IN	deprel: case	feats:    _
# oil	NOUN	NN	deprel: compound	feats:    Number=Sing
# flushing	NOUN	NN	deprel: nmod	feats:    Number=Sing
# (	PUNCT	-LRB-	deprel: punct	feats:    _
# pending	VERB	VBG	deprel: amod	feats:    VerbForm=Ger
# top	NOUN	NN	deprel: appos	feats:    Number=Sing
# )	PUNCT	-RRB-	deprel: punct	feats:    _
# ******************************
# name: cold commissioning, oil flushing, motor rotation checks, motor solo run
# spacy:
# token    POS    TAG    Dep    POS explained        tag explained
# cold     ADJ           JJ     amod   adjective            adjective (English), other noun-modifier (Chinese)
# commissioning NOUN          NN     ROOT   noun                 noun, singular or mass
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# oil      NOUN          NN     compound noun                 noun, singular or mass
# flushing NOUN          NN     conj   noun                 noun, singular or mass
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# motor    NOUN          NN     compound noun                 noun, singular or mass
# rotation NOUN          NN     compound noun                 noun, singular or mass
# checks   NOUN          NNS    conj   noun                 noun, plural
# ,        PUNCT         ,      punct  punctuation          punctuation mark, comma
# motor    NOUN          NN     compound noun                 noun, singular or mass
# solo     NOUN          NN     compound noun                 noun, singular or mass
# run      NOUN          NN     appos  noun                 noun, singular or mass
# stanza:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RONYAR~1\AppData\Local\Temp/ipykernel_18808/348418720.py in <module>
#       1 for name in names:
# ----> 2     print_pos(name)
#
# C:\Users\RONYAR~1\AppData\Local\Temp/ipykernel_18808/844580142.py in print_pos(sentence)
#       8         {token.tag_:{6}} {token.dep_:{6}} {spacy.explain(token.pos_):{20}} {spacy.explain(token.tag_)}')
#       9     print('stanza:')
# ---> 10     doc = stanza_nlp(sentence)
#      11     print(*[f'{word.text}\t{word.upos}\t{word.xpos}\tdeprel: {word.deprel}\tfeats:\
#      12     {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
#
# ~\anaconda3\lib\site-packages\stanza\pipeline\core.py in __call__(self, doc)
#     229         assert any([isinstance(doc, str), isinstance(doc, list),
#     230                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 231         doc = self.process(doc)
#     232         return doc
#     233
#
# ~\anaconda3\lib\site-packages\stanza\pipeline\core.py in process(self, doc)
#     223             if self.processors.get(processor_name):
#     224                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 225                 doc = process(doc)
#     226         return doc
#     227
#
# ~\anaconda3\lib\site-packages\stanza\pipeline\lemma_processor.py in process(self, document)
#      69             edits = []
#      70             for i, b in enumerate(seq2seq_batch):
# ---> 71                 ps, es = self.trainer.predict(b, self.config['beam_size'])
#      72                 preds += ps
#      73                 if es is not None:
#
# ~\anaconda3\lib\site-packages\stanza\models\lemma\trainer.py in predict(self, batch, beam_size)
#      89         self.model.eval()
#      90         batch_size = src.size(0)
# ---> 91         preds, edit_logits = self.model.predict(src, src_mask, pos=pos, beam_size=beam_size)
#      92         pred_seqs = [self.vocab['char'].unmap(ids) for ids in preds] # unmap to tokens
#      93         pred_seqs = utils.prune_decoded_seqs(pred_seqs)
#
# ~\anaconda3\lib\site-packages\stanza\models\common\seq2seq_model.py in predict(self, src, src_mask, pos, beam_size)
#     247         """ Predict with beam search. """
#     248         if beam_size == 1:
# --> 249             return self.predict_greedy(src, src_mask, pos=pos)
#     250
#     251         enc_inputs = self.embedding(src)
#
# ~\anaconda3\lib\site-packages\stanza\models\common\seq2seq_model.py in predict_greedy(self, src, src_mask, pos)
#     229
#     230         while total_done < batch_size and max_len < self.max_dec_len:
# --> 231             log_probs, (hn, cn) = self.decode(dec_inputs, hn, cn, h_in, src_mask, src=src)
#     232             assert log_probs.size(1) == 1, "Output must have 1-step of output."
#     233             _, preds = log_probs.squeeze(1).max(1, keepdim=True)
#
# ~\anaconda3\lib\site-packages\stanza\models\common\seq2seq_model.py in decode(self, dec_inputs, hn, cn, ctx, ctx_mask, src)
#     130         """ Decode a step, based on context encoding and source context states."""
#     131         dec_hidden = (hn, cn)
# --> 132         decoder_output = self.decoder(dec_inputs, dec_hidden, ctx, ctx_mask, return_logattn=self.copy)
#     133         if self.copy:
#     134             h_out, dec_hidden, log_attn = decoder_output
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\stanza\models\common\seq2seq_modules.py in forward(self, input, hidden, ctx, ctx_mask, return_logattn)
#     225         steps = range(input.size(0))
#     226         for i in steps:
# --> 227             hidden = self.lstm_cell(input[i], hidden)
#     228             hy, cy = hidden
#     229             h_tilde, alpha = self.attention_layer(hy, ctx, mask=ctx_mask, return_logattn=return_logattn)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#    1065             zeros = torch.zeros(input.size(0), self.hidden_size, dtype=input.dtype, device=input.device)
#    1066             hx = (zeros, zeros)
# -> 1067         return _VF.lstm_cell(
#    1068             input, hx,
#    1069             self.weight_ih, self.weight_hh,
#
# KeyboardInterrupt:

# %%
sentences = ["Get busy living or get busy dying.", "Barack Obama was born in Hawaii. He was elected president in 2008."]

# %%
for sentence in sentences:
    print_pos(sentence)
# Out:
# token    POS    TAG    Dep    POS explained        tag explained
# Get      VERB          VB     ROOT   verb                 verb, base form
# busy     ADJ           JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# living   VERB          VBG    xcomp  verb                 verb, gerund or present participle
# or       CCONJ         CC     cc     coordinating conjunction conjunction, coordinating
# get      VERB          VB     conj   verb                 verb, base form
# busy     ADJ           JJ     acomp  adjective            adjective (English), other noun-modifier (Chinese)
# dying    VERB          VBG    xcomp  verb                 verb, gerund or present participle
# .        PUNCT         .      punct  punctuation          punctuation mark, sentence closer
# ----
# Get	VERB	VB	deprel: root	feats:    Mood=Imp|VerbForm=Fin
# busy	ADJ	JJ	deprel: amod	feats:    Degree=Pos
# living	NOUN	NN	deprel: obj	feats:    Number=Sing
# or	CCONJ	CC	deprel: cc	feats:    _
# get	VERB	VB	deprel: conj	feats:    Mood=Imp|VerbForm=Fin
# busy	ADJ	JJ	deprel: xcomp	feats:    Degree=Pos
# dying	VERB	VBG	deprel: xcomp	feats:    VerbForm=Ger
# .	PUNCT	.	deprel: punct	feats:    _
# ******************************
# comparison:test1
# ******************************
# token    POS    TAG    Dep    POS explained        tag explained
# Barack   PROPN         NNP    compound proper noun          noun, proper singular
# Obama    PROPN         NNP    nsubjpass proper noun          noun, proper singular
# was      AUX           VBD    auxpass auxiliary            verb, past tense
# born     VERB          VBN    ROOT   verb                 verb, past participle
# in       ADP           IN     prep   adposition           conjunction, subordinating or preposition
# Hawaii   PROPN         NNP    pobj   proper noun          noun, proper singular
# .        PUNCT         .      punct  punctuation          punctuation mark, sentence closer
# He       PRON          PRP    nsubjpass pronoun              pronoun, personal
# was      AUX           VBD    auxpass auxiliary            verb, past tense
# elected  VERB          VBN    ROOT   verb                 verb, past participle
# president NOUN          NN     oprd   noun                 noun, singular or mass
# in       ADP           IN     prep   adposition           conjunction, subordinating or preposition
# 2008     NUM           CD     pobj   numeral              cardinal number
# .        PUNCT         .      punct  punctuation          punctuation mark, sentence closer
# ----
# Barack	PROPN	NNP	deprel: nsubj:pass	feats:    Number=Sing
# Obama	PROPN	NNP	deprel: flat	feats:    Number=Sing
# was	AUX	VBD	deprel: aux:pass	feats:    Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# born	VERB	VBN	deprel: root	feats:    Tense=Past|VerbForm=Part|Voice=Pass
# in	ADP	IN	deprel: case	feats:    _
# Hawaii	PROPN	NNP	deprel: obl	feats:    Number=Sing
# .	PUNCT	.	deprel: punct	feats:    _
# He	PRON	PRP	deprel: nsubj:pass	feats:    Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# was	AUX	VBD	deprel: aux:pass	feats:    Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# elected	VERB	VBN	deprel: root	feats:    Tense=Past|VerbForm=Part|Voice=Pass
# president	NOUN	NN	deprel: xcomp	feats:    Number=Sing
# in	ADP	IN	deprel: case	feats:    _
# 2008	NUM	CD	deprel: obl	feats:    NumForm=Digit|NumType=Card
# .	PUNCT	.	deprel: punct	feats:    _
# ******************************
# comparison:test2
# ******************************
