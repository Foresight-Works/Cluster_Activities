# %%
import torch
import warnings
warnings.filterwarnings('ignore')
import re
import gensim.downloader as api
import pandas as pd
import os
import numpy as np
from sentence_transformers import SentenceTransformer, util
import random

# %%
model_w2v = api.load("word2vec-google-news-300")
#model_w2v.vocab

# %%
type (model_w2v)
# Out:
# gensim.models.keyedvectors.Word2VecKeyedVectors

# %%
results_dir = 'C:\\Users\\RonyArmon\\Projects_Code\\Cluster_Activities\\results'
names = open(os.path.join(results_dir, 'names.txt')).read().split('\n')
names = list(set(names))
#names = names[:100]
print('{} names'.format(len(names)))
# Out:
# 17077 names

# %% [markdown]
# # Name vectors
# Mean pooling of token vectors

# %%
punctuation_marks="=|\+|_|\.|:|\/|\*|\'|,|\?|-|\(|\)|{|}|\[|\]"
names_embeddings, names_not_in_vocab, embed_names = [], [], []
names = [n for n in names if n]
for index, name in enumerate(names):
#     print(50*'-')
#     print('name:',index, name)
    name = re.sub(punctuation_marks,' ', name)
    name = re.sub('\s{2,}', ' ', name)
    token_embeddings = []
    tokens = name.split(' ')
    tokens = [t for t in tokens if len(t)>1]
    not_in_vocab = []
    for token in tokens:
        if token in model_w2v.vocab:
            token_embedding = model_w2v[token]
            token_embeddings.append(token_embedding)
        else:
            not_in_vocab.append(token)
    token_embeddings = np.array(token_embeddings)
    if (len(token_embeddings))>0:
        name_embedding = token_embeddings.mean(axis=0)
        name_embedding = torch.tensor(name_embedding)
        names_embeddings.append(name_embedding)
        embed_names.append(name)
        names_not_in_vocab.append(not_in_vocab)
names_embeddings = torch.stack(names_embeddings)

# %%
print(type(names_embeddings), names_embeddings.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([17069, 300])

# %%
sample = random.choices(range(len(names)), k=100)
results_df = pd.DataFrame()
#for name_index in range(len(names)):
for name_index in sample:
    query = names[name_index]
    name_embedding = names_embeddings[name_index]
    cosine_scores = util.cos_sim(name_embedding, names_embeddings)
    cosine_scores = list(cosine_scores[0])
    cosine_scores = [float(s) for s in cosine_scores]
    sorted_scores = cosine_scores.copy()
    sorted_scores.sort(reverse = True)
    top10_scores = sorted_scores[:10]
    top10_scores = [i for i in top10_scores if i>0.7]
    results = []
    for score in top10_scores: 
        score_index = cosine_scores.index(score)
        name = names[score_index]
        if score>0.9999: score = 'query'
        else: score = round(score, 2)
        results.append([name, score])
    result_df = pd.DataFrame(results, columns = ['name', 'score'])
    #print(50*'-')
    #print('query:', query)
    #if len (result_df)==0: print('no cluster')
    #else: display(result_df.style.set_properties(**{'text-align': 'left', 'colheader_justify':'left'}))
    if len (result_df)>1:
        results_df = results_df.append(result_df)

# %%
results_df.head(50)
# Out:
#                                                 name  score
# 0              142a - landscape master plan revision  query
# 1    erection piping system (outside) 20pab20-spool6    0.9
# 2                              termination of tp-f1a    0.9
# 3                              termination of tp-f1a    0.9
# 4                              termination of tp-f1a    0.9
# 5                              termination of tp-f1a    0.9
# 6                              termination of tp-f1a    0.9
# 7                              termination of tp-f1a    0.9
# 8                              termination of tp-f1a    0.9
# 9                              termination of tp-f1a    0.9
# 0                              5 kv ei's - ifr/ ifoa  query
# 1  event 043 - socketed h-pile amendment (type ii...   0.82
# 2      design / manufacturing st bypass module 20man   0.78
# 3                   cems  - receive vendor proposals   0.78
# 4          install stg gland steam [431] a/g lb pipe   0.77
# 5  complete lightbulb testing (portions after bac...   0.77
# 6  instrument air ct-1b notification of turnover ...   0.77
# 7                                  fine grade ctg 1b   0.76
# 8   circulating water chemical feed resolve p1 items   0.74
# 9            lv mcc one lines - revise / check / ifc   0.74
# 0  test preparation & assembly  test facility 20u...  query
# 1  waste water - ows, basin & outfall constructio...   0.96
# 2  lube oil system ct-1c complete ps-1 punchlist ...   0.93
# 3  manufacturing / shop test condensate polishing...   0.92
# 4  f/r/p ctg 1a ct vt & surge cubicle [148] found...   0.89
# 5  instrument air (main header) pre-commission an...   0.88
# 6  logistics and customs preparation module 20upy00y   0.87
# 7                 ct - 1c fuel oil system motor pdma   0.86
# 8  f/r/p ctg 1c iso phase bus duct [128] foundations   0.86
# 9  b/e/a/fab/deliver mh #1 rebar (s road & road e...   0.86
# 0                 combustion turbine 1c sfi checkout  query
# 1           tube bundles  - internal review / revise   0.96
# 2            install containment tank sr-2 - fo tank   0.96
# 3                               gauges -owner review   0.95
# 4                   install new vertical splice bars   0.95
# 5   hoist and trolley  - review vendor drawings (st)   0.94
# 6          finger rack 1b hp steam sb [441] a/g pipe   0.93
# 7          fo tank foundations - design / ifr / ifoa   0.92
# 8  bd - submission & approval - detail design con...   0.92
# 9  bd - submission & approval - detail design con...   0.92
# 0  event 039(tx) - mv aux.tx / conduct plate load...  query
# 1  hrsg flue gas side 3 system turnover walk with...   0.91
# 2                 install stg condensate pumps [056]    0.9
# 3  event 055 - 1800 drainage pipe at sbr / excava...   0.81
# 4                       ug pipe backfill - wsac area    0.8
# 5  f/r/p hrsg 1a duct brnr & pr red skid [154/155...    0.8
# 6                         checkout of exhauster fans   0.79
# 7     closed cooling water install jumpers for flush   0.78
# 8              f/r/p sst breaker - 115kv [811a] fdns   0.76
# 9  install ctg 1a fuel gas i/c pipe & supports [3...   0.76
