# %% [markdown]
# # Names normalization using the nltk stemmers and lemmatizer

# %%
from prep import *
import nltk
#nltk.download('wordnet')
#nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer
from nltk.stem.snowball import EnglishStemmer
import stanza

nlp = stanza.Pipeline(lang="en", use_gpu= True)
def lemmatize_text (text):
    '''
    :params:
    text: input text
    param1: stanza's language model
    :return: list of token-lemma tuple for each token in text
    '''

    text_tokens_lemmas = []
    doc = nlp(text)
    tokens_lemmas = [(word.text, word.lemma) \
                     for sent in doc.sentences for word in sent.words]
    for token_lemma in tokens_lemmas:
        token = token_lemma[0]
        lemma = token_lemma[1]
        #print('{t}:{l}'.format(t=token, l=lemma))
        if ('_' not in token) and (token != lemma) and (lemma != 'None'):
            text_tokens_lemmas.append(token_lemma)

    return text, text_tokens_lemmas

task_names = task_names[:1000]
start = time.time()
names_tokens_lemmas = []
print('analyzing {n} sentences'.format(n=len(task_names)))
for index, name in enumerate(task_names):
    print('name number ', index+1)
    name = name.lower()
    name, name_tokens_lemmas = lemmatize_text(name)
    if name_tokens_lemmas:
        print(30*'-')
        #print('task name:               ', name)
        print('tokens, different lemmas:', name_tokens_lemmas)
        names_tokens_lemmas += name_tokens_lemmas
end = time.time()
print('duration=', end-start)
# Out:
# 2021-12-26 09:11:50 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2021-12-26 09:11:50 INFO: Use device: cpu
# 2021-12-26 09:11:50 INFO: Loading: tokenize
# 2021-12-26 09:11:50 INFO: Loading: pos
# 2021-12-26 09:11:50 INFO: Loading: lemma
# 2021-12-26 09:11:50 INFO: Loading: depparse
# 2021-12-26 09:11:50 INFO: Loading: sentiment
# 2021-12-26 09:11:51 INFO: Loading: constituency
# 2021-12-26 09:11:51 INFO: Loading: ner
# 2021-12-26 09:11:52 INFO: Done loading processors!
# analyzing 1000 sentences
# name number  1
# ------------------------------
# tokens, different lemmas: [('stated', 'state')]
# name number  2
# name number  3
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('works', 'work')]
# name number  4
# name number  5
# ------------------------------
# tokens, different lemmas: [('tunnels', 'tunnel')]
# name number  6
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  7
# name number  8
# name number  9
# name number  10
# name number  11
# name number  12
# name number  13
# name number  14
# name number  15
# name number  16
# name number  17
# name number  18
# name number  19
# name number  20
# name number  21
# name number  22
# name number  23
# name number  24
# name number  25
# name number  26
# name number  27
# name number  28
# name number  29
# name number  30
# name number  31
# name number  32
# name number  33
# name number  34
# name number  35
# name number  36
# name number  37
# name number  38
# name number  39
# name number  40
# name number  41
# name number  42
# name number  43
# name number  44
# name number  45
# name number  46
# name number  47
# name number  48
# name number  49
# name number  50
# name number  51
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  52
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('proposed', 'propose')]
# name number  53
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  54
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  55
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  56
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  57
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('proposed', 'propose')]
# name number  58
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('proposed', 'propose')]
# name number  59
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  60
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('proposed', 'propose')]
# name number  61
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  62
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  63
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  64
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  65
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  66
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  67
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  68
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  69
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  70
# name number  71
# name number  72
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  73
# name number  74
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('may', 'May')]
# name number  75
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  76
# name number  77
# ------------------------------
# tokens, different lemmas: [('tunnels', 'tunnel')]
# name number  78
# name number  79
# name number  80
# name number  81
# name number  82
# name number  83
# name number  84
# name number  85
# ------------------------------
# tokens, different lemmas: [('specified', 'specify'), ('plans', 'plan')]
# name number  86
# ------------------------------
# tokens, different lemmas: [('launching', 'launch')]
# name number  87
# ------------------------------
# tokens, different lemmas: [('passages', 'passage')]
# name number  88
# ------------------------------
# tokens, different lemmas: [('designated', 'designate')]
# name number  89
# ------------------------------
# tokens, different lemmas: [('specified', 'specify'), ('plans', 'plan')]
# name number  90
# ------------------------------
# tokens, different lemmas: [('specified', 'specify'), ('plans', 'plan')]
# name number  91
# ------------------------------
# tokens, different lemmas: [('designated', 'designate')]
# name number  92
# ------------------------------
# tokens, different lemmas: [('specified', 'specify'), ('plans', 'plan')]
# name number  93
# name number  94
# ------------------------------
# tokens, different lemmas: [('plans', 'plan')]
# name number  95
# ------------------------------
# tokens, different lemmas: [('plans', 'plan')]
# name number  96
# name number  97
# ------------------------------
# tokens, different lemmas: [('manuals', 'manual'), ('built', 'build'), ('drawings', 'drawing')]
# name number  98
# ------------------------------
# tokens, different lemmas: [('mauls', 'maul')]
# name number  99
# ------------------------------
# tokens, different lemmas: [('may', 'May')]
# name number  100
# ------------------------------
# tokens, different lemmas: [('submissions', 'submission')]
# name number  101
# name number  102
# ------------------------------
# tokens, different lemmas: [('segments', 'segment')]
# name number  103
# ------------------------------
# tokens, different lemmas: [('segments', 'segment')]
# name number  104
# name number  105
# name number  106
# name number  107
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  108
# name number  109
# name number  110
# name number  111
# name number  112
# ------------------------------
# tokens, different lemmas: [('may', 'May')]
# name number  113
# name number  114
# name number  115
# name number  116
# name number  117
# name number  118
# name number  119
# name number  120
# name number  121
# name number  122
# name number  123
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  124
# name number  125
# ------------------------------
# tokens, different lemmas: [('segments', 'segment')]
# name number  126
# ------------------------------
# tokens, different lemmas: [('segments', 'segment')]
# name number  127
# name number  128
# name number  129
# name number  130
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  131
# name number  132
# name number  133
# ------------------------------
# tokens, different lemmas: [('games', 'game')]
# name number  134
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  135
# name number  136
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  137
# name number  138
# name number  139
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  140
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  141
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  142
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  143
# name number  144
# name number  145
# name number  146
# name number  147
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  148
# name number  149
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  150
# name number  151
# name number  152
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  153
# name number  154
# name number  155
# name number  156
# ------------------------------
# tokens, different lemmas: [('components', 'component')]
# name number  157
# ------------------------------
# tokens, different lemmas: [('components', 'component')]
# name number  158
# name number  159
# name number  160
# name number  161
# name number  162
# name number  163
# name number  164
# ------------------------------
# tokens, different lemmas: [('bracing', 'brace'), ('brackets', 'bracket'), ('corbels', 'corbel')]
# name number  165
# name number  166
# name number  167
# name number  168
# name number  169
# name number  170
# name number  171
# name number  172
# name number  173
# ------------------------------
# tokens, different lemmas: [('components', 'component')]
# name number  174
# ------------------------------
# tokens, different lemmas: [('components', 'component')]
# name number  175
# name number  176
# name number  177
# name number  178
# name number  179
# name number  180
# name number  181
# ------------------------------
# tokens, different lemmas: [('bracing', 'brace'), ('brackets', 'bracket'), ('corbels', 'corbel')]
# name number  182
# name number  183
# name number  184
# name number  185
# name number  186
# name number  187
# name number  188
# name number  189
# name number  190
# name number  191
# name number  192
# name number  193
# ------------------------------
# tokens, different lemmas: [('mixed', 'mix')]
# name number  194
# name number  195
# ------------------------------
# tokens, different lemmas: [('mixed', 'mix')]
# name number  196
# name number  197
# name number  198
# name number  199
# name number  200
# name number  201
# name number  202
# name number  203
# name number  204
# name number  205
# name number  206
# name number  207
# ------------------------------
# tokens, different lemmas: [('anticipated', 'anticipate')]
# name number  208
# name number  209
# name number  210
# name number  211
# name number  212
# name number  213
# name number  214
# ------------------------------
# tokens, different lemmas: [('moving', 'move')]
# name number  215
# ------------------------------
# tokens, different lemmas: [('ttms', 'ttm')]
# name number  216
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  217
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing'), ("'", "'s")]
# name number  218
# name number  219
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  220
# name number  221
# name number  222
# ------------------------------
# tokens, different lemmas: [('mixed', 'mix')]
# name number  223
# name number  224
# ------------------------------
# tokens, different lemmas: [('mixed', 'mix')]
# name number  225
# name number  226
# name number  227
# name number  228
# name number  229
# name number  230
# name number  231
# name number  232
# name number  233
# name number  234
# name number  235
# ------------------------------
# tokens, different lemmas: [('anticipated', 'anticipate')]
# name number  236
# name number  237
# name number  238
# name number  239
# name number  240
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  241
# name number  242
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  243
# name number  244
# name number  245
# name number  246
# name number  247
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  248
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  249
# name number  250
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  251
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  252
# ------------------------------
# tokens, different lemmas: [('including', 'include')]
# name number  253
# name number  254
# name number  255
# name number  256
# name number  257
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  258
# name number  259
# name number  260
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  261
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  262
# name number  263
# name number  264
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  265
# name number  266
# name number  267
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  268
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  269
# name number  270
# ------------------------------
# tokens, different lemmas: [('including', 'include')]
# name number  271
# name number  272
# name number  273
# name number  274
# name number  275
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  276
# ------------------------------
# tokens, different lemmas: [('including', 'include')]
# name number  277
# name number  278
# name number  279
# name number  280
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  281
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  282
# name number  283
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  284
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  285
# name number  286
# name number  287
# name number  288
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  289
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  290
# name number  291
# name number  292
# name number  293
# name number  294
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  295
# name number  296
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  297
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  298
# ------------------------------
# tokens, different lemmas: [('including', 'include')]
# name number  299
# name number  300
# name number  301
# name number  302
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  303
# name number  304
# name number  305
# name number  306
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  307
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  308
# name number  309
# name number  310
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  311
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  312
# ------------------------------
# tokens, different lemmas: [('drilling', 'drill'), ('remaining', 'remain'), ('holes', 'hole')]
# name number  313
# name number  314
# name number  315
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  316
# name number  317
# name number  318
# name number  319
# name number  320
# name number  321
# name number  322
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  323
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  324
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  325
# name number  326
# ------------------------------
# tokens, different lemmas: [('holes', 'hole')]
# name number  327
# ------------------------------
# tokens, different lemmas: [('pipes', 'pipe')]
# name number  328
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  329
# ------------------------------
# tokens, different lemmas: [('including', 'include')]
# name number  330
# name number  331
# name number  332
# name number  333
# name number  334
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  335
# name number  336
# name number  337
# name number  338
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  339
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  340
# name number  341
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  342
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze'), ('holes', 'hole')]
# name number  343
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  344
# ------------------------------
# tokens, different lemmas: [('commissioning', 'commission')]
# name number  345
# name number  346
# name number  347
# ------------------------------
# tokens, different lemmas: [('sides', 'side')]
# name number  348
# name number  349
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  350
# name number  351
# name number  352
# ------------------------------
# tokens, different lemmas: [('doors', 'door')]
# name number  353
# name number  354
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  355
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  356
# name number  357
# ------------------------------
# tokens, different lemmas: [('passed', 'pass'), ('passed', 'pass')]
# name number  358
# name number  359
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  360
# name number  361
# name number  362
# name number  363
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  364
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  365
# name number  366
# name number  367
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze'), ('holes', 'hole')]
# name number  368
# ------------------------------
# tokens, different lemmas: [('passed', 'pass'), ('passed', 'pass')]
# name number  369
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  370
# name number  371
# ------------------------------
# tokens, different lemmas: [('achieved', 'achieve')]
# name number  372
# name number  373
# name number  374
# ------------------------------
# tokens, different lemmas: [('working', 'work')]
# name number  375
# name number  376
# name number  377
# name number  378
# name number  379
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  380
# name number  381
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  382
# ------------------------------
# tokens, different lemmas: [('sides', 'side')]
# name number  383
# name number  384
# name number  385
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  386
# ------------------------------
# tokens, different lemmas: [('passed', 'pass'), ('passed', 'pass')]
# name number  387
# name number  388
# ------------------------------
# tokens, different lemmas: [('exited', 'exit')]
# name number  389
# name number  390
# ------------------------------
# tokens, different lemmas: [('pipes', 'pipe')]
# name number  391
# name number  392
# name number  393
# name number  394
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  395
# ------------------------------
# tokens, different lemmas: [('walls', 'wall')]
# name number  396
# name number  397
# name number  398
# name number  399
# ------------------------------
# tokens, different lemmas: [('passed', 'pass')]
# name number  400
# name number  401
# ------------------------------
# tokens, different lemmas: [('drilling', 'drill'), ('remaining', 'remain'), ('holes', 'hole'), ('gantries', 'gantry'), ('passed', 'pass')]
# name number  402
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  403
# ------------------------------
# tokens, different lemmas: [("'", "'s")]
# name number  404
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  405
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  406
# name number  407
# name number  408
# name number  409
# name number  410
# name number  411
# name number  412
# name number  413
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp')]
# name number  414
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  415
# name number  416
# name number  417
# name number  418
# name number  419
# name number  420
# name number  421
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  422
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  423
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  424
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  425
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  426
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  427
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  428
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  429
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  430
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  431
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  432
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  433
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  434
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  435
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate')]
# name number  436
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate'), ('mps', 'mp')]
# name number  437
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  438
# ------------------------------
# tokens, different lemmas: [('brackets', 'bracket')]
# name number  439
# ------------------------------
# tokens, different lemmas: [('brackets', 'bracket')]
# name number  440
# name number  441
# name number  442
# name number  443
# name number  444
# name number  445
# name number  446
# name number  447
# name number  448
# name number  449
# name number  450
# name number  451
# name number  452
# name number  453
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  454
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  455
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp')]
# name number  456
# name number  457
# name number  458
# name number  459
# name number  460
# name number  461
# name number  462
# name number  463
# name number  464
# name number  465
# name number  466
# name number  467
# name number  468
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  469
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp')]
# name number  470
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  471
# ------------------------------
# tokens, different lemmas: [('brackets', 'bracket')]
# name number  472
# ------------------------------
# tokens, different lemmas: [('brackets', 'bracket')]
# name number  473
# name number  474
# name number  475
# name number  476
# name number  477
# name number  478
# name number  479
# name number  480
# name number  481
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  482
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp')]
# name number  483
# ------------------------------
# tokens, different lemmas: [('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  484
# name number  485
# name number  486
# name number  487
# name number  488
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  489
# ------------------------------
# tokens, different lemmas: [("'", "'s")]
# name number  490
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  491
# ------------------------------
# tokens, different lemmas: [('gates', 'gate')]
# name number  492
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  493
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  494
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  495
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wks', 'wk')]
# name number  496
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  497
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  498
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  499
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  500
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  501
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  502
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  503
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky')]
# name number  504
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate')]
# name number  505
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate'), ('mps', 'mp')]
# name number  506
# ------------------------------
# tokens, different lemmas: [('lower', 'low'), ('wkys', 'wky'), ('gates', 'gate'), ('mps', 'mp'), ('mps', 'mp')]
# name number  507
# name number  508
# ------------------------------
# tokens, different lemmas: [('trials', 'trial')]
# name number  509
# ------------------------------
# tokens, different lemmas: [('segments', 'segment')]
# name number  510
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  511
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  512
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  513
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  514
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  515
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  516
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  517
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  518
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  519
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  520
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  521
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  522
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  523
# ------------------------------
# tokens, different lemmas: [('rings', 'ring'), ('rings', 'ring')]
# name number  524
# ------------------------------
# tokens, different lemmas: [('rings', 'ring'), ('rings', 'ring')]
# name number  525
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  526
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  527
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  528
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  529
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  530
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  531
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  532
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  533
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  534
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  535
# ------------------------------
# tokens, different lemmas: [('rings', 'ring')]
# name number  536
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing'), ('issued', 'issue')]
# name number  537
# name number  538
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  539
# ------------------------------
# tokens, different lemmas: [('materials', 'material')]
# name number  540
# name number  541
# ------------------------------
# tokens, different lemmas: [('sets', 'set')]
# name number  542
# ------------------------------
# tokens, different lemmas: [('commissioning', 'commission')]
# name number  543
# ------------------------------
# tokens, different lemmas: [('moulds', 'mould')]
# name number  544
# ------------------------------
# tokens, different lemmas: [('sets', 'set')]
# name number  545
# name number  546
# name number  547
# name number  548
# name number  549
# ------------------------------
# tokens, different lemmas: [('electrics', 'electric')]
# name number  550
# name number  551
# ------------------------------
# tokens, different lemmas: [('freezing', 'freeze')]
# name number  552
# name number  553
# ------------------------------
# tokens, different lemmas: [('mixed', 'mix')]
# name number  554
# ------------------------------
# tokens, different lemmas: [('manufacturing', 'manufacture'), ('parts', 'part')]
# name number  555
# name number  556
# name number  557
# name number  558
# ------------------------------
# tokens, different lemmas: [('runs', 'run')]
# name number  559
# ------------------------------
# tokens, different lemmas: [('runs', 'run')]
# name number  560
# name number  561
# name number  562
# name number  563
# name number  564
# name number  565
# ------------------------------
# tokens, different lemmas: [('thru', 'through')]
# name number  566
# name number  567
# ------------------------------
# tokens, different lemmas: [('thru', 'through')]
# name number  568
# name number  569
# name number  570
# ------------------------------
# tokens, different lemmas: [('manufacturing', 'manufacture'), ('parts', 'part')]
# name number  571
# name number  572
# name number  573
# name number  574
# name number  575
# name number  576
# name number  577
# ------------------------------
# tokens, different lemmas: [('drawing', 'draw')]
# name number  578
# ------------------------------
# tokens, different lemmas: [('drawing', 'draw')]
# name number  579
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  580
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  581
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing'), ('issued', 'issue')]
# name number  582
# ------------------------------
# tokens, different lemmas: [('operations', 'operation')]
# name number  583
# name number  584
# ------------------------------
# tokens, different lemmas: [('components', 'component'), ('materials', 'material')]
# name number  585
# name number  586
# ------------------------------
# tokens, different lemmas: [('drawing', 'draw')]
# name number  587
# ------------------------------
# tokens, different lemmas: [('drawing', 'draw')]
# name number  588
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  589
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  590
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing'), ('issued', 'issue')]
# name number  591
# name number  592
# name number  593
# ------------------------------
# tokens, different lemmas: [('docks', 'dock')]
# name number  594
# ------------------------------
# tokens, different lemmas: [('customs', 'custom')]
# name number  595
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  596
# name number  597
# name number  598
# ------------------------------
# tokens, different lemmas: [('operations', 'operation')]
# name number  599
# ------------------------------
# tokens, different lemmas: [('commissioning', 'commission')]
# name number  600
# name number  601
# ------------------------------
# tokens, different lemmas: [('logistics', 'logistic'), ('plans', 'plan')]
# name number  602
# ------------------------------
# tokens, different lemmas: [('logistics', 'logistic'), ('plans', 'plan')]
# name number  603
# ------------------------------
# tokens, different lemmas: [('designs', 'design')]
# name number  604
# ------------------------------
# tokens, different lemmas: [('designs', 'design')]
# name number  605
# name number  606
# name number  607
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  608
# name number  609
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  610
# name number  611
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  612
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  613
# name number  614
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  615
# name number  616
# name number  617
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  618
# name number  619
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  620
# name number  621
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  622
# name number  623
# name number  624
# name number  625
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  626
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  627
# name number  628
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  629
# name number  630
# name number  631
# name number  632
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  633
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  634
# name number  635
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  636
# name number  637
# name number  638
# name number  639
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  640
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  641
# name number  642
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  643
# name number  644
# name number  645
# name number  646
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  647
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  648
# name number  649
# name number  650
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  651
# name number  652
# name number  653
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  654
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  655
# name number  656
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  657
# name number  658
# name number  659
# name number  660
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  661
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  662
# name number  663
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  664
# name number  665
# name number  666
# name number  667
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  668
# name number  669
# name number  670
# name number  671
# name number  672
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  673
# name number  674
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  675
# name number  676
# name number  677
# name number  678
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  679
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  680
# name number  681
# ------------------------------
# tokens, different lemmas: [('checking', 'check')]
# name number  682
# name number  683
# name number  684
# name number  685
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  686
# ------------------------------
# tokens, different lemmas: [('closed', 'close'), ('permits', 'permit')]
# name number  687
# ------------------------------
# tokens, different lemmas: [('proposals', 'proposal'), ('procedures', 'procedure')]
# name number  688
# ------------------------------
# tokens, different lemmas: [('proposals', 'proposal'), ('procedures', 'procedure')]
# name number  689
# ------------------------------
# tokens, different lemmas: [('permits', 'permit')]
# name number  690
# name number  691
# name number  692
# name number  693
# name number  694
# name number  695
# name number  696
# name number  697
# name number  698
# ------------------------------
# tokens, different lemmas: [('rolling', 'roll')]
# name number  699
# ------------------------------
# tokens, different lemmas: [('rolling', 'roll')]
# name number  700
# name number  701
# name number  702
# name number  703
# name number  704
# ------------------------------
# tokens, different lemmas: [('s', "'s")]
# name number  705
# name number  706
# name number  707
# name number  708
# ------------------------------
# tokens, different lemmas: [('measures', 'measure')]
# name number  709
# name number  710
# name number  711
# name number  712
# name number  713
# name number  714
# name number  715
# name number  716
# name number  717
# name number  718
# name number  719
# name number  720
# name number  721
# ------------------------------
# tokens, different lemmas: [('f', 'for')]
# name number  722
# ------------------------------
# tokens, different lemmas: [('instruments', 'instrument')]
# name number  723
# ------------------------------
# tokens, different lemmas: [('instruments', 'instrument')]
# name number  724
# name number  725
# name number  726
# ------------------------------
# tokens, different lemmas: [('surveying', 'survey'), ('works', 'work')]
# name number  727
# ------------------------------
# tokens, different lemmas: [('surveying', 'survey'), ('works', 'work')]
# name number  728
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  729
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  730
# name number  731
# name number  732
# ------------------------------
# tokens, different lemmas: [('tbms', 'tbm')]
# name number  733
# ------------------------------
# tokens, different lemmas: [('tbms', 'tbm')]
# name number  734
# name number  735
# name number  736
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('areas', 'area')]
# name number  737
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  738
# ------------------------------
# tokens, different lemmas: [('determining', 'determine'), ('conditions', 'condition')]
# name number  739
# ------------------------------
# tokens, different lemmas: [('determining', 'determine'), ('conditions', 'condition')]
# name number  740
# name number  741
# name number  742
# ------------------------------
# tokens, different lemmas: [('commencing', 'commence'), ('drives', 'drive')]
# name number  743
# ------------------------------
# tokens, different lemmas: [('commencing', 'commence'), ('drives', 'drive')]
# name number  744
# ------------------------------
# tokens, different lemmas: [('setting', 'set'), ('controlling', 'control')]
# name number  745
# ------------------------------
# tokens, different lemmas: [('setting', 'set'), ('contolling', 'contol')]
# name number  746
# ------------------------------
# tokens, different lemmas: [('monitoring', 'monitor')]
# name number  747
# ------------------------------
# tokens, different lemmas: [('interventions', 'intervention')]
# name number  748
# ------------------------------
# tokens, different lemmas: [('interventions', 'intervention')]
# name number  749
# ------------------------------
# tokens, different lemmas: [('obstructions', 'obstruction')]
# name number  750
# ------------------------------
# tokens, different lemmas: [('monitoring', 'monitor')]
# name number  751
# ------------------------------
# tokens, different lemmas: [('obstructions', 'obstruction')]
# name number  752
# ------------------------------
# tokens, different lemmas: [('tunnelling', 'tunnel'), ('structures', 'structure')]
# name number  753
# ------------------------------
# tokens, different lemmas: [('tunnelling', 'tunnel'), ('structures', 'structure')]
# name number  754
# name number  755
# name number  756
# ------------------------------
# tokens, different lemmas: [('junctions', 'junction'), ('shafts', 'shaft')]
# name number  757
# ------------------------------
# tokens, different lemmas: [('junctions', 'junction'), ('shafts', 'shaft')]
# name number  758
# name number  759
# name number  760
# name number  761
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  762
# name number  763
# name number  764
# name number  765
# ------------------------------
# tokens, different lemmas: [('methods', 'method')]
# name number  766
# ------------------------------
# tokens, different lemmas: [('methods', 'method')]
# name number  767
# name number  768
# ------------------------------
# tokens, different lemmas: [('assignments', 'assignment')]
# name number  769
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('areas', 'area')]
# name number  770
# ------------------------------
# tokens, different lemmas: [('works', 'work'), ('areas', 'area')]
# name number  771
# name number  772
# name number  773
# name number  774
# name number  775
# name number  776
# name number  777
# name number  778
# name number  779
# name number  780
# name number  781
# name number  782
# name number  783
# name number  784
# name number  785
# ------------------------------
# tokens, different lemmas: [('ttms', 'ttm')]
# name number  786
# ------------------------------
# tokens, different lemmas: [('ttms', 'ttm')]
# name number  787
# name number  788
# name number  789
# ------------------------------
# tokens, different lemmas: [('ttms', 'ttm')]
# name number  790
# ------------------------------
# tokens, different lemmas: [('built', 'build'), ('drawings', 'drawing')]
# name number  791
# ------------------------------
# tokens, different lemmas: [('built', 'build'), ('drawings', 'drawing')]
# name number  792
# ------------------------------
# tokens, different lemmas: [('built', 'build'), ('drawings', 'drawing')]
# name number  793
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  794
# name number  795
# name number  796
# name number  797
# name number  798
# name number  799
# name number  800
# name number  801
# name number  802
# name number  803
# name number  804
# name number  805
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  806
# name number  807
# name number  808
# name number  809
# name number  810
# name number  811
# name number  812
# name number  813
# name number  814
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  815
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  816
# name number  817
# name number  818
# name number  819
# name number  820
# name number  821
# name number  822
# name number  823
# name number  824
# name number  825
# name number  826
# name number  827
# name number  828
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  829
# name number  830
# name number  831
# name number  832
# name number  833
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  834
# name number  835
# name number  836
# name number  837
# name number  838
# name number  839
# name number  840
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  841
# name number  842
# name number  843
# name number  844
# name number  845
# name number  846
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  847
# name number  848
# name number  849
# name number  850
# name number  851
# name number  852
# name number  853
# name number  854
# name number  855
# name number  856
# name number  857
# name number  858
# name number  859
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  860
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  861
# name number  862
# name number  863
# name number  864
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  865
# name number  866
# ------------------------------
# tokens, different lemmas: [('g', 'gram')]
# name number  867
# ------------------------------
# tokens, different lemmas: [('g', 'gram'), ('blasting', 'blast'), ('features', 'feature')]
# name number  868
# name number  869
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast'), ('blasting', 'blast'), ('licences', 'licence'), ('permits', 'permit')]
# name number  870
# ------------------------------
# tokens, different lemmas: [('blasting', 'blast')]
# name number  871
# name number  872
# name number  873
# name number  874
# name number  875
# name number  876
# name number  877
# name number  878
# name number  879
# name number  880
# ------------------------------
# tokens, different lemmas: [('drawings', 'drawing')]
# name number  881
# name number  882
# name number  883
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  884
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  885
# name number  886
# name number  887
# name number  888
# ------------------------------
# tokens, different lemmas: [('hoarding', 'hoard')]
# name number  889
# name number  890
# name number  891
# name number  892
# name number  893
# name number  894
# name number  895
# name number  896
# name number  897
# name number  898
# name number  899
# name number  900
# ------------------------------
# tokens, different lemmas: [('affected', 'affect'), ('drains', 'drain')]
# name number  901
# name number  902
# name number  903
# ------------------------------
# tokens, different lemmas: [('cables', 'cable')]
# name number  904
# ------------------------------
# tokens, different lemmas: [('works', 'work')]
# name number  905
# ------------------------------
# tokens, different lemmas: [('finishing', 'finish'), ('works', 'work')]
# name number  906
# name number  907
# name number  908
# name number  909
# ------------------------------
# tokens, different lemmas: [('footings', 'footing')]
# name number  910
# name number  911
# ------------------------------
# tokens, different lemmas: [('bollards', 'bollard')]
# name number  912
# name number  913
# name number  914
# name number  915
# name number  916
# name number  917
# name number  918
# name number  919
# name number  920
# name number  921
# name number  922
# name number  923
# name number  924
# name number  925
# name number  926
# name number  927
# name number  928
# name number  929
# name number  930
# name number  931
# name number  932
# name number  933
# name number  934
# name number  935
# name number  936
# name number  937
# name number  938
# name number  939
# name number  940
# name number  941
# name number  942
# name number  943
# name number  944
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  945
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  946
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  947
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  948
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  949
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  950
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  951
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  952
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  953
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  954
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  955
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  956
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  957
# name number  958
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  959
# ------------------------------
# tokens, different lemmas: [('lower', 'low')]
# name number  960
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  961
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  962
# ------------------------------
# tokens, different lemmas: [('utilities', 'utility')]
# name number  963
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  964
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  965
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  966
# name number  967
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  968
# name number  969
# name number  970
# name number  971
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  972
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  973
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  974
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  975
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  976
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  977
# ------------------------------
# tokens, different lemmas: [('w', 'with')]
# name number  978
# name number  979
# name number  980
# name number  981
# name number  982
# name number  983
# ------------------------------
# tokens, different lemmas: [('rooms', 'room')]
# name number  984
# ------------------------------
# tokens, different lemmas: [('rooms', 'room')]
# name number  985
# ------------------------------
# tokens, different lemmas: [('slabs', 'slab')]
# name number  986
# ------------------------------
# tokens, different lemmas: [('slabs', 'slab')]
# name number  987
# ------------------------------
# tokens, different lemmas: [('slabs', 'slab')]
# name number  988
# ------------------------------
# tokens, different lemmas: [('slabs', 'slab')]
# name number  989
# ------------------------------
# tokens, different lemmas: [('slabs', 'slab')]
# name number  990
# name number  991
# name number  992
# name number  993
# name number  994
# name number  995
# name number  996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7e84b0e30923> in <module>
#      36     print('name number ', index+1)
#      37     name = name.lower()
# ---> 38     name, name_tokens_lemmas = lemmatize_text(name)
#      39     if name_tokens_lemmas:
#      40         print(30*'-')
#
# <ipython-input-4-7e84b0e30923> in lemmatize_text(text)
#      17
#      18     text_tokens_lemmas = []
# ---> 19     doc = nlp(text)
#      20     tokens_lemmas = [(word.text, word.lemma) \
#      21                      for sent in doc.sentences for word in sent.words]
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/pipeline/core.py in __call__(self, doc)
#     229         assert any([isinstance(doc, str), isinstance(doc, list),
#     230                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 231         doc = self.process(doc)
#     232         return doc
#     233
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/pipeline/core.py in process(self, doc)
#     223             if self.processors.get(processor_name):
#     224                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 225                 doc = process(doc)
#     226         return doc
#     227
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/pipeline/pos_processor.py in process(self, document)
#      39         else:
#      40             for i, b in enumerate(batch):
# ---> 41                 preds += self.trainer.predict(b)
#      42
#      43         preds = unsort(preds, batch.data_orig_idx)
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/models/pos/trainer.py in predict(self, batch, unsort)
#      71         self.model.eval()
#      72         batch_size = word.size(0)
# ---> 73         _, preds = self.model(word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, word_orig_idx, sentlens, wordlens)
#      74         upos_seqs = [self.vocab['upos'].unmap(sent) for sent in preds[0].tolist()]
#      75         xpos_seqs = [self.vocab['xpos'].unmap(sent) for sent in preds[1].tolist()]
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/models/pos/model.py in forward(self, word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, word_orig_idx, sentlens, wordlens)
#     120         lstm_inputs = PackedSequence(lstm_inputs, inputs[0].batch_sizes)
#     121
# --> 122         lstm_outputs, _ = self.taggerlstm(lstm_inputs, sentlens, hx=(self.taggerlstm_h_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous(), self.taggerlstm_c_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous()))
#     123         lstm_outputs = lstm_outputs.data
#     124
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/models/common/hlstm.py in forward(self, input, seqlens, hx)
#     102                 input = PackedSequence(self.drop(input.data), input.batch_sizes, input.sorted_indices, input.unsorted_indices)
#     103             layer_hx = (hx[0][l * self.num_directions:(l+1)*self.num_directions], hx[1][l * self.num_directions:(l+1)*self.num_directions]) if hx is not None else None
# --> 104             h, (ht, ct) = self.lstm[l](input, seqlens, layer_hx)
#     105
#     106             hs.append(ht)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.7/site-packages/stanza/models/common/packed_lstm.py in forward(self, input, lengths, hx)
#      20             input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
#      21
# ---> 22         res = self.lstm(input, hx)
#      23         if self.pad:
#      24             res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     693         else:
#     694             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
# --> 695                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     696         output = result[0]
#     697         hidden = result[1:]
#
# KeyboardInterrupt:

# %%
unique_tokens_lemas = list(set(names_tokens_lemmas)) 
print(unique_tokens_lemas)
# Out:
# [('1,367', '1367'), ('cylinders', 'cylinder'), ('services', 'service'), ('4,277', '4277'), ('m.s', 'm.'), ('placing', 'place'), ('bridges', 'bridge'), ('parts', 'part'), ('utiltiies', 'utiltiy'), ('pre-drilling', 'pre-dril'), ('weeks', 'week'), ('2,608', '2608'), ('corridors', 'corridor'), ('approved', 'approve'), ('tunnelling', 'tunnel'), ('devices', 'device'), ('stairs', 'stair'), ('backs', 'back'), ('poured', 'pour'), ('pipes', 'pipe'), ('dismantling', 'dismantle'), ('risers', 'riser'), ('procedures', 'procedure'), ('accessories', 'accessory'), ('leading', 'lead'), ('1,292', '1292'), ('purchasing', 'purchase'), ('sams', 'sam'), ('26,322', '26322'), ('8,781', '8781'), ('i', 'I'), ('chartered', 'charter'), ('fixed', 'fix'), ('rms', 'rm'), ('running', 'run'), ('grating', 'grate'), ('1,130', '1130'), ('demolished', 'demolish'), ('5,052', '5052'), ('defects', 'defect'), ('2,076', '2076'), ('10,694', '10694'), ('repositioning', 'reposition'), ('1,560', '1560'), ('footing', 'foot'), ('bollards', 'bollard'), ('10,270', '10270'), ('hoarding', 'hoard'), ('2,330', '2330'), ('fitting', 'fit'), ('windows', 'window'), ('handing', 'hand'), ('8nos', '8no'), ('lower', 'low'), ('watermains', 'watermain'), ('changed', 'change'), ('saw', 'see'), ('ttms', 'ttm'), ('ladders', 'ladder'), ('weighbridges', 'weighbridge'), ('kerbs', 'kerb'), ('requirements', 'requirement'), ('�', "''"), ('foundations', 'foundation'), ('grouting', 'grout'), ('shum', 'Shum'), ('piles', 'pile'), ('1,205', '1205'), ('manufacturing', 'manufacture'), ('8,382', '8382'), ('1,029', '1029'), ('stiles', 'stile'), ('1,283', '1283'), ('10,191', '10191'), ('6,500', '6500'), ('�', 'at'), ('1,011', '1011'), ('backfilling', 'backfil'), ('roads', 'road'), ('1,110', '1110'), ('4,185', '4185'), ('leaving', 'leave'), ('props', 'prop'), ('plinths', 'plinth'), ('moorings', 'mooring'), ('trees', 'tree'), ('jumbos', 'jumbo'), ('holes', 'hole'), ("poc's", "poc'"), ('9,435', '9435'), ('9,247', '9247'), ('1,496', '1496'), ('approvals', 'approval'), ('climbers', 'climber'), ('1,372', '1372'), ('methods', 'method'), ('licences', 'licence'), ('penetrations', 'penetration'), ('tbms', 'tbm'), ('pulls', 'pull'), ('4,804', '4804'), ('rending', 'rend'), ('16,248', '16248'), ('lrs', 'lr'), ('pits', 'pit'), ('1,131', '1131'), ('closing', 'close'), ('1,443', '1443'), ('copping', 'cop'), ('stockpiling', 'stockpile'), ('sets', 'set'), ('lv', 'lve'), ('d-walls', 'd-wall'), ('ramps', 'ramp'), ('lobbies', 'lobby'), ('formworks', 'formwork'), ('5,890', '5890'), ('backfilled', 'backfill'), ('8,571', '8571'), ('groundcovers', 'groundcover'), ('extended', 'extend'), ('5,854', '5854'), ('1,974', '1974'), ('raking', 'rake'), ('tests', 'test'), ('components', 'component'), ('antiquities', 'antiquity'), ('trucks', 'truck'), ('blasts', 'blast'), ('4,976', '4976'), ('working', 'work'), ('3,510', '3510'), ('6,746', '6746'), ('leaks', 'leak'), ('surveying', 'survey'), ('enabling', 'enable'), ('f', 'for'), ('aquased', 'aquase'), ('bars', 'bar'), ('railing', 'rail'), ('5,250', '5250'), ('7,048', '7048'), ('3,032', '3032'), ('entrances', 'entrance'), ('docks', 'dock'), ('remaining', 'remain'), ('16,163', '16163'), ('completed', 'complete'), ('5,988', '5988'), ('crushing', 'crush'), ('ups', 'up'), ('enlarged', 'enlarge'), ('transplanted', 'transplant'), ('underpinning', 'underpin'), ('20nos', '20no'), ('designated', 'designate'), ('corbels', 'corbel'), ('signs', 'sign'), ('roadworks', 'roadwork'), ('12,348', '12348'), ('segments', 'segment'), ('wells', 'well'), ('checking', 'check'), ('sprayed', 'spray'), ('sides', 'side'), ("'", "'s"), ('sleeves', 'sleeve'), ('screeding', 'screed'), ('covers', 'cover'), ('mounted', 'mount'), ('energized', 'energize'), ('cells', 'cell'), ('monitoring', 'monitor'), ('arresting', 'arrest'), ('1,211', '1211'), ('confirmed', 'confirm'), ('buildings', 'building'), ('sidewalls', 'sidewall'), ('gaps', 'gap'), ('drwgs', 'drwg'), ('heads', 'head'), ('loading', 'load'), ('realigned', 'realign'), ('mod ...

# %% [markdown]
# # Observations
# ### Calculation Duration
# Lemmatizing all sentences takes a long time (40 minutes and running)
#
# ### Results
# 1. Verbs: Lemmas appear to be useful to normalize inflections:
# 'specified', 'specify'; 'designated', 'designate'; 'built', 'build'
# 2. Nouns: Plural form lemmas may be misleading as the plural form may indicate a significant difference in work load:
# 'tunnels' -> 'tunnel', 'gates' -> 'gate', 'wkys', 'wky'
# <font color='red'>! Lemmatization or another process to distinguish plural from singular forms may be useful to identify dissimilarities between tasks </font>
# difflib.ndiff may also be useful to distinguish plural from singular forms: https://stackoverflow.com/questions/17904097/python-difference-between-two-strings/17904977
